# %% [markdown]
# Optimal Charging and Routing of Electric Vehicles (EVs)
#
# Objective:
#
# Routing Optimization: Determine the most efficient routes for EVs from origin to destination considering factors like distance, traffic, and road conditions.
#
# Charging Optimization: Identify optimal charging stations along the route to minimize charging time and costs while ensuring EVs do not deplete their batteries.
#
# ***
#
# Key Features:
#
# Integration of real-time or historical traffic data.
#
# Battery level monitoring and prediction.
#
# Charging station availability and pricing optimization.
#
# User preferences (e.g., fastest route vs. cheapest charging options).

# %%
# Dataset:  https://data.open-power-system-data.org/renewable_power_plants/2020-08-25

# %%
# !pip install osmnx

# %%
# !pip install pulp

# %%
import osmnx as ox
import requests
import pandas as pd
from pandas import json_normalize
from geopy.geocoders import Nominatim
import networkx as nx
import folium
# Example using PuLP for linear optimization
from pulp import LpProblem, LpMinimize, LpVariable, lpSum, LpBinary

# %% [markdown]
# ## Data Collection and Preprocessing
#
# a. Retrieve EV Charging Stations Data

# %%
# EV Charging Stations Dataset (Open Charge Map):

# https://openchargemap.org/site/develop/api

# Road Network and Routing Data (OpenStreetMap):

# https://www.openstreetmap.org/

# Traffic Data:

# HERE Traffic API: https://developer.here.com/products/traffic

# OpenTraffic: https://opentraffic.io/

# EV Specifications (EPA Vehicle Data):

# https://www.fueleconomy.gov/feg/ws/index.shtml

# ------------------------------------------------------------------------------

# Example using Open Charge Map API
API_KEY = 'API'  # Replace with your API key
url = 'https://api.openchargemap.io/v3/poi/'

params = {
    'output': 'json',
    'countrycode': 'US',  # Specify country code as needed
    'maxresults': 1000,
    'compact': True,
    'verbose': False,
    'key': API_KEY
}

response = requests.get(url, params=params)
charging_data = response.json()

# %%
charging_data
# Out:
# [{'IsRecentlyVerified': True,
#   'DateLastVerified': '2024-09-03T15:39:00Z',
#   'ID': 303710,
#   'UUID': 'F456E474-7EBB-4E63-833C-682F84E2558C',
#   'DataProviderID': 1,
#   'OperatorID': 5,
#   'UsageTypeID': 5,
#   'UsageCost': '$0.50/kWh',
#   'AddressInfo': {'ID': 304099,
#    'Title': 'Melloy Dodge',
#    'AddressLine1': '9621 Coors Blvd',
#    'Town': 'Albuquerque',
#    'StateOrProvince': 'New Mexico',
#    'Postcode': '87114',
#    'CountryID': 2,
#    'Latitude': 35.18991807180117,
#    'Longitude': -106.63638615493508,
#    'AccessComments': 'South entrance',
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 573214,
#     'ConnectionTypeID': 1,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 80,
#     'Voltage': 208,
#     'PowerKW': 19.2,
#     'CurrentTypeID': 10,
#     'Quantity': 2,
#     'Comments': 'Near Building'},
#    {'ID': 573215,
#     'ConnectionTypeID': 32,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'Amps': 200,
#     'Voltage': 480,
#     'PowerKW': 125,
#     'CurrentTypeID': 30,
#     'Quantity': 2,
#     'Comments': 'Under solar canopy'},
#    {'ID': 573216,
#     'ConnectionTypeID': 2,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'Amps': 200,
#     'Voltage': 480,
#     'PowerKW': 125,
#     'CurrentTypeID': 30,
#     'Quantity': 2,
#     'Comments': 'Under solar canopy'},
#    {'ID': 573217,
#     'ConnectionTypeID': 32,
#     'StatusTypeID': 30,
#     'LevelID': 3,
#     'Amps': 400,
#     'Voltage': 480,
#     'PowerKW': 180,
#     'CurrentTypeID': 30,
#     'Quantity': 2,
#     'Comments': 'Under solar canopy'}],
#   'NumberOfPoints': 4,
#   'GeneralComments': '7:30am - 6:00pm',
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-09-03T15:39:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2024-08-31T15:38:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2024-08-22T18:32:00Z',
#   'ID': 303216,
#   'UUID': '1FEF1580-B913-48EF-A9A1-558878700F03',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 303603,
#    'Title': 'Fremont Chevrolet Buick GMC',
#    'AddressLine1': '1401 North Federal Boulevard',
#    'Town': 'Riverton',
#    'StateOrProvince': 'Wyoming',
#    'Postcode': '82501',
#    'CountryID': 2,
#    'Latitude': 43.038698,
#    'Longitude': -108.379586,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 570377,
#     'ConnectionTypeID': 32,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'PowerKW': 60,
#     'Quantity': 2}],
#   'NumberOfPoints': 2,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-08-22T18:32:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2024-08-19T19:21:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2024-08-31T05:59:00Z',
#   'ID': 303210,
#   'UUID': 'B99174F1-2D3C-4A1E-BCC2-8FD10DD6E539',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 1,
#   'UsageCost': 'Free',
#   'AddressInfo': {'ID': 303597,
#    'Title': 'G&C EV Charging Station',
#    'AddressLine1': '14008-A Willard Road',
#    'Town': 'Chantilly',
#    'StateOrProvince': 'Virginia',
#    'Postcode': '20151',
#    'CountryID': 2,
#    'Latitude': 38.886197553000244,
#    'Longitude': -77.43160352567253,
#    'ContactTelephone1': '703-263-2742',
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 570365,
#     'ConnectionTypeID': 27,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 28,
#     'Voltage': 240,
#     'PowerKW': 6.7,
#     'Quantity': 1}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-08-31T05:59:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2024-08-19T13:42:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2024-08-31T05:59:00Z',
#   'ID': 303209,
#   'UUID': 'B623F026-118A-4311-BB42-DB7CC60B7066',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 4,
#   'UsageCost': 'Free - but...   please post a picture, digital check in, google review, or more - please and thank you.',
#   'AddressInfo': {'ID': 303596,
#    'Title': 'G&C EV Juice Bar Manassas',
#    'AddressLine1': '11707 Pump Station Way',
#    'Town': 'Manassas',
#    'StateOrProvince': 'Virginia',
#    'Postcode': '20109',
#    'CountryID': 2,
#    'Latitude': 38.892351195279616,
#    'Longitude': -77.42136103348895,
#    'ContactTelephone1': '703-365-9072',
#    'AccessComments': 'Open 24/7',
#    'RelatedURL': 'http://www.TrustTheRepair.com',
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 570363,
#     'ConnectionTypeID': 27,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 28,
#     'Voltage': 240,
#     'PowerKW': 35.5,
#     'Quantity': 1,
#     'Comments': 'We have two chargers mounted side by side.  This one is a Tesla charger.'},
#    {'ID': 570364,
#     'ConnectionTypeID': 1,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 28,
#     'Voltage': 240,
#     'PowerKW': 40.5,
#     'CurrentTypeID': 20,
#     'Quantity': 1,
#     'Comments': 'Please give us feedback on improvements we can make.  '}],
#   'NumberOfPoints': 2,
#   'GeneralComments': "We installed these chargers for our customers and as a way to meet new EV oners and the EV's that they drive. ",
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-08-31T05:59:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2024-08-19T13:38:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2024-08-31T05:59:00Z',
#   'ID': 303208,
#   'UUID': '827ECCD6-8203-4669-84B2-FF761DFA20D5',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 1,
#   'UsageCost': 'Post a picture, check in, and google review - please and thank you',
#   'AddressInfo': {'ID': 303595,
#    'Title': 'G&C EV Juice Bar',
#    'AddressLine1': '14008 Willard Road',
#    'Town': 'Chantilly',
#    'StateOrProvince': 'Virginia',
#    'Postcode': '20151',
#    'CountryID': 2,
#    'Latitude': 38.878001501011596,
#    'Longitude': -77.44322237359353,
#    'ContactTelephone1': '703-263-2474',
#    'ContactTelephone2': '703-365-9072',
#    'AccessComments': 'Please return charging cable to wall holder.  No unattended charging or sleeping onsite.',
#    'RelatedURL': 'http://www.TrustTheRepair.com',
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 570361,
#     'ConnectionTypeID': 1,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 25,
#     'Voltage': 220,
#     'PowerKW': 30,
#     'CurrentTypeID': 20,
#     'Quantity': 2,
#     'Comments': 'Two Tesla chargers - one mounted on each corner of the building.'},
#    {'ID': 570362,
#     'ConnectionTypeID': 27,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 30,
#     'Voltage': 240,
#     'PowerKW': 40,
#     'CurrentTypeID': 20,
#     'Quantity': 2,
#     'Comments': 'One is located on each corner of the building.   '}],
#   'NumberOfPoints': 4,
#   'GeneralComments': "We provide this as a free courtesy to meet new EV owners and the EV's they drive.",
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-08-31T05:59:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2024-08-19T13:29:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2024-08-31T05:59:00Z',
#   'ID': 303184,
#   'UUID': '11A344DF-5078-46E6-9EBF-78E62F7808CA',
#   'DataProviderID': 1,
#   'OperatorID': 3372,
#   'UsageTypeID': 6,
#   'UsageCost': '.20',
#   'AddressInfo': {'ID': 303571,
#    'Title': '2nd Century Towers',
#    'AddressLine1': '200 S. California St.',
#    'Town': 'Burbank',
#    'StateOrProvince': 'CA',
#    'Postcode': '91522',
#    'CountryID': 2,
#    'Latitude': 34.15293010908157,
#    'Longitude': -118.33420509400239,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 570193,
#     'ConnectionTypeID': 1,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'PowerKW': 8,
#     'Quantity': 1}],
#   'NumberOfPoints': 40,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-08-31T05:59:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2024-08-18T22:53:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2024-08-30T09:28:00Z',
#   'ID': 303163,
#   'UUID': '81014C3A-2118-45DC-B091-CE924BC3059E',
#   'DataProviderID': 1,
#   'OperatorID': 3618,
#   'UsageTypeID': 1,
#   'AddressInfo': {'ID': 303550,
#    'Title': 'Victory Park',
#    'AddressLine1': '2575 Paloma Street',
#    'Town': 'Pasadena',
#    'StateOrProvince': 'California',
#    'Postcode': '91107',
#    'CountryID': 2,
#    'Latitude': 34.1594339873393,
#    'Longitude': -118.09618567907086,
#    'AccessComments': 'Public parking lot.  No parking fee.',
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 570063,
#     'ConnectionTypeID': 1,
#     'StatusTypeID': 50,
#     'Quantity': 19},
#    {'ID': 570064,
#     'ConnectionTypeID': 32,
#     'StatusTypeID': 100,
#     'LevelID': 2,
#     'PowerKW': 50,
#     'Quantity': 3},
#    {'ID': 570065,
#     'ConnectionTypeID': 2,
#     'StatusTypeID': 100,
#     'LevelID': 2,
#     'PowerKW': 50,
#     'Quantity': 3}],
#   'NumberOfPoints': 26,
#   'StatusTypeID': 75,
#   'DateLastStatusUpdate': '2024-08-30T09:28:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2024-08-17T17:12:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2024-09-02T01:49:00Z',
#   'ID': 302920,
#   'UUID': '58CCED5E-1127-4BD6-87B4-AC48D56D52B6',
#   'DataProviderID': 1,
#   'OperatorID': 5,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 303307,
#    'Title': 'ChargeNet TacoBell Santa Rosa',
#    'AddressLine1': '771 Story Point Road',
#    'Town': 'Santa Rosa',
#    'StateOrProvince': 'CA',
#    'Postcode': '95407',
#    'CountryID': 2,
#    'Latitude': 38.4269951144708,
#    'Longitude': -122.74183082068888,
#    'RelatedURL': 'https://chargenetstations.com/',
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 569536,
#     'ConnectionTypeID': 32,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 75,
#     'CurrentTypeID': 30,
#     'Quantity': 5},
#    {'ID': 569537,
#     'ConnectionTypeID': 2,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 75,
#     'CurrentTypeID': 30,
#     'Quantity': 5}],
#   'NumberOfPoints': 5,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-09-02T01:49:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2024-08-15T21:23:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2024-09-02T01:49:00Z',
#   'ID': 302912,
#   'UUID': '292A6312-56D1-4D2F-B7A2-6AF494F5AE34',
#   'DataProviderID': 1,
#   'OperatorID': 5,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 303299,
#    'Title': 'ChargeNet TacoBell Rohnert Park',
#    'AddressLine1': '5000 Redwood Drive',
#    'Town': 'Rohnert Park',
#    'StateOrProvince': 'CA',
#    'Postcode': '94928',
#    'CountryID': 2,
#    'Latitude': 38.36461322180173,
#    'Longitude': -122.71344046563185,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 569527,
#     'ConnectionTypeID': 32,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 75,
#     'CurrentTypeID': 30,
#     'Quantity': 4},
#    {'ID': 569528,
#     'ConnectionTypeID': 2,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 75,
#     'CurrentTypeID': 30,
#     'Quantity': 4}],
#   'NumberOfPoints': 6,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-09-02T01:49:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2024-08-15T21:19:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2024-09-02T01:49:00Z',
#   'ID': 302908,
#   'UUID': '6AC7B9BC-B9D3-44BF-A88A-4A5E2B6A8E69',
#   'DataProviderID': 1,
#   'OperatorID': 5,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 303295,
#    'Title': 'Chipotle Quad District',
#    'AddressLine1': '2650 Arena Boulevard',
#    'Town': 'Sacramento',
#    'StateOrProvince': 'CA',
#    'Postcode': '95834',
#    'CountryID': 2,
#    'Latitude': 38.642369674200125,
#    'Longitude': -121.52122601887885,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 569523,
#     'ConnectionTypeID': 1,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 32,
#     'Voltage': 208,
#     'PowerKW': 6.6,
#     'CurrentTypeID': 10,
#     'Quantity': 2}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-09-02T01:49:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2024-08-15T21:13:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2024-09-02T01:59:00Z',
#   'ID': 302586,
#   'UUID': '4E9A16DF-3955-4451-AF7E-66743220C9D5',
#   'DataProviderID': 1,
#   'OperatorID': 3318,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 302973,
#    'Title': 'Cosrco Natomas',
#    'AddressLine1': '3881 East Commercial Way',
#    'Town': 'Sacramento',
#    'StateOrProvince': 'CA',
#    'Postcode': '95834',
#    'CountryID': 2,
#    'Latitude': 38.63925956136708,
#    'Longitude': -121.52193258906195,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 568720,
#     'ConnectionTypeID': 32,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'Voltage': 1000,
#     'PowerKW': 350,
#     'CurrentTypeID': 30,
#     'Quantity': 10}],
#   'NumberOfPoints': 10,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-09-02T01:59:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2024-08-14T05:06:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2024-08-03T22:49:00Z',
#   'ID': 302221,
#   'UUID': '88C77BD3-7B41-4978-86E0-60061E9F4C73',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 1,
#   'UsageCost': '$0.45/ kWh',
#   'AddressInfo': {'ID': 302608,
#    'Title': 'Lundgren Ford ',
#    'AddressLine1': '900 Old Hwy 53,,',
#    'Town': 'Eveleth',
#    'StateOrProvince': 'MN',
#    'Postcode': '55734',
#    'CountryID': 2,
#    'Latitude': 47.47806172507245,
#    'Longitude': -92.53259144129288,
#    'RelatedURL': 'https://go.ford/fordcharge',
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 566422,
#     'ConnectionTypeID': 32,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 240,
#     'CurrentTypeID': 30,
#     'Quantity': 2,
#     'Comments': 'uo to 240 kW - split to 120 each if 2 vehicles are charging '}],
#   'NumberOfPoints': 2,
#   'GeneralComments': 'Available 24/7 Ford Network ',
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-08-03T22:49:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2024-07-31T22:47:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2024-08-01T14:59:00Z',
#   'ID': 302165,
#   'UUID': '4ACC10A6-AB96-4697-AE09-CB43566895AA',
#   'DataProviderID': 1,
#   'OperatorID': 3372,
#   'UsageTypeID': 5,
#   'UsageCost': '$0.59/kwh',
#   'AddressInfo': {'ID': 302552,
#    'Title': 'City of Sheridan',
#    'AddressLine1': '4101 S. Federal Blvd.',
#    'Town': 'Sheridan',
#    'StateOrProvince': 'Colorado',
#    'Postcode': '80110',
#    'CountryID': 2,
#    'Latitude': 39.64129320147245,
#    'Longitude': -105.02736468715621,
#    'RelatedURL': 'https://www.ci.sheridan.co.us/534/Transportation',
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 566095,
#     'ConnectionTypeID': 32,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 120,
#     'CurrentTypeID': 30,
#     'Quantity': 2},
#    {'ID': 566096,
#     'ConnectionTypeID': 2,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 120,
#     'CurrentTypeID': 30,
#     'Quantity': 2}],
#   'NumberOfPoints': 2,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-08-01T14:59:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2024-07-29T14:57:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2024-07-29T04:25:00Z',
#   'ID': 302155,
#   'UUID': '824B1A1B-9057-40B9-885C-7C4C20203915',
#   'DataProviderID': 1,
#   'OperatorID': 5,
#   'UsageTypeID': 6,
#   'AddressInfo': {'ID': 302542,
#    'Title': 'Boulder Ridge Street',
#    'AddressLine1': 'Boulder Ridge Street',
#    'Town': 'Central Point',
#    'StateOrProvince': 'Oregon',
#    'Postcode': '97502',
#    'CountryID': 2,
#    'Latitude': 42.38087772919863,
#    'Longitude': -122.92729158401062,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 566077,
#     'ConnectionTypeID': 1,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'PowerKW': 4,
#     'Quantity': 2}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-07-29T04:25:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2024-07-29T04:25:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2024-07-29T02:49:00Z',
#   'ID': 301866,
#   'UUID': '2A84580A-5FAA-4548-AEFF-6D8C7610B853',
#   'DataProviderID': 1,
#   'OperatorID': 3295,
#   'UsageTypeID': 5,
#   'AddressInfo': {'ID': 302253,
#    'Title': 'SoMa Square Apartments',
#    'AddressLine1': '1 St. Francis Place',
#    'Town': 'San Francisco',
#    'StateOrProvince': 'California',
#    'Postcode': '94105',
#    'CountryID': 2,
#    'Latitude': 37.78331760416101,
#    'Longitude': -122.39776558534226,
#    'ContactTelephone1': '678-412-0505',
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 564965,
#     'ConnectionTypeID': 1,
#     'StatusTypeID': 50,
#     'Amps': 48,
#     'Quantity': 30,
#     'Comments': 'EverCharge'}],
#   'NumberOfPoints': 30,
#   'GeneralComments': 'Must pay for parking AND charging separately.',
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-07-29T02:49:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2024-07-25T22:49:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2024-07-29T02:49:00Z',
#   'ID': 301824,
#   'UUID': '62049C08-2271-43D6-A4F0-53AD8E414E36',
#   'DataProviderID': 1,
#   'OperatorID': 3534,
#   'UsageTypeID': 1,
#   'AddressInfo': {'ID': 302211,
#    'Title': 'Franklin Plaza',
#    'AddressLine1': 'Franklin Plaza',
#    'Town': 'Franklin',
#    'StateOrProvince': 'North Carolina',
#    'Postcode': '28734',
#    'CountryID': 2,
#    'Latitude': 35.164261775933184,
#    'Longitude': -83.39282765284946,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 564873,
#     'ConnectionTypeID': 27,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 250,
#     'CurrentTypeID': 30,
#     'Quantity': 12}],
#   'NumberOfPoints': 12,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-07-29T02:49:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2024-07-24T18:00:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2024-07-26T06:19:00Z',
#   'ID': 301415,
#   'UUID': '6F40B74E-ECFB-44F2-A5C9-F345A9BF74A6',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 1,
#   'UsageCost': '0',
#   'AddressInfo': {'ID': 301802,
#    'Title': 'Gilman Street',
#    'AddressLine1': 'Gilman Street',
#    'StateOrProvince': 'Tennessee',
#    'Postcode': '37874',
#    'CountryID': 2,
#    'Latitude': 35.599430509455615,
#    'Longitude': -84.4609428753173,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 563266,
#     'ConnectionTypeID': 1,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'PowerKW': 7,
#     'CurrentTypeID': 10,
#     'Quantity': 2}],
#   'NumberOfPoints': 2,
#   'GeneralComments': 'On the side away from the rail road tracks',
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-07-26T06:19:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2024-07-19T22:40:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2024-07-26T06:19:00Z',
#   'ID': 301414,
#   'UUID': 'EF312478-FEB0-4D5A-8382-ABAD6BE5898B',
#   'DataProviderID': 1,
#   'OperatorID': 3510,
#   'UsageTypeID': 5,
#   'UsageCost': '.43',
#   'AddressInfo': {'ID': 301801,
#    'Title': 'Circle K',
#    'AddressLine1': '2302 W Market',
#    'Town': 'Bloomington ',
#    'StateOrProvince': 'illinois ',
#    'Postcode': '61705',
#    'CountryID': 2,
#    'Latitude': 40.48681541026161,
#    'Longitude': -89.04519131952935,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 563264,
#     'ConnectionTypeID': 32,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 180,
#     'CurrentTypeID': 30,
#     'Quantity': 3},
#    {'ID': 563265,
#     'ConnectionTypeID': 2,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 180,
#     'CurrentTypeID': 30,
#     'Quantity': 1}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-07-26T06:19:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2024-07-19T18:20:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2024-07-30T09:22:00Z',
#   'ID': 301144,
#   'UUID': '69B1F0F2-DD55-489C-956A-59E30351961A',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 1,
#   'UsageCost': '$.35/kWh',
#   'AddressInfo': {'ID': 301531,
#    'Title': 'Dahl Ford',
#    'AddressLine1': '561 Theater Rd',
#    'Town': 'Onalaska',
#    'StateOrProvince': 'WI',
#    'Postcode': '54650',
#    'CountryID': 2,
#    'Latitude': 43.874942727047454,
#    'Longitude': -91.19587112238173,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 562036,
#     'ConnectionTypeID': 32,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'PowerKW': 240,
#     'Quantity': 1},
#    {'ID': 563039,
#     'ConnectionTypeID': 32,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'PowerKW': 240,
#     'Quantity': 1,
#     'Comments': '2 240 kW chargers, each supporting 2 EVs'}],
#   'NumberOfPoints': 4,
#   'GeneralComments': 'CPO is Ford Charge',
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-07-30T09:22:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2024-07-16T02:46:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2024-07-15T07:12:00Z',
#   'ID': 301087,
#   'UUID': '0643C834-C63F-4B84-88CE-5383420552E7',
#   'DataProviderID': 1,
#   'OperatorID': 5,
#   'UsageTypeID': 1,
#   'UsageCost': '0',
#   'AddressInfo': {'ID': 301474,
#    'Title': 'Rusted Gate Farm store',
#    'AddressLine1': '5700 Upton Road',
#    'Town': 'Central Point',
#    'StateOrProvince': 'OR',
#    'Postcode': '97502',
#    'CountryID': 2,
#    'Latitude': 42.39987796386592,
#    'Longitude': -122.90701103283186,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 561902,
#     'ConnectionTypeID': 1,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'PowerKW': 8,
#     'Quantity': 2}],
#   'NumberOfPoints': 2,
#   'GeneralComments': 'Open at the farm store, charger is beyond the front gate and usable when gate is open. Store open Tuesday through Friday, 10 AM to 5:30 PM, and Saturday, 10 AM to 4 PM according to website.',
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-07-15T07:12:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2024-07-15T07:12:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2024-07-26T06:19:00Z',
#   'ID': 300897,
#   'UUID': 'CC38C33E-ECE4-4A04-BC35-80EE4B21A9FD',
#   'DataProviderID': 1,
#   'OperatorID': 15,
#   'UsageTypeID': 1,
#   'UsageCost': '$0.63/kWh',
#   'AddressInfo': {'ID': 301284,
#    'Title': 'Flying J 656 - eXtend',
#    'AddressLine1': '82 White Street',
#    'Town': 'Whiteland',
#    'StateOrProvince': 'IN',
#    'Postcode': '46184',
#    'CountryID': 2,
#    'Latitude': 39.55008552679013,
#    'Longitude': -86.0362241722429,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 561315,
#     'ConnectionTypeID': 32,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 350,
#     'CurrentTypeID': 30,
#     'Quantity': 4}],
#   'NumberOfPoints': 4,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-07-26T06:19:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2024-07-13T11:45:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2024-07-12T08:34:00Z',
#   'ID': 300585,
#   'UUID': '1DCF5944-F007-4C41-B587-4940EDEF135E',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 1,
#   'UsageCost': '$0.50 start',
#   'AddressInfo': {'ID': 300972,
#    'Title': 'Public Parking Garage - Greenspot charging',
#    'AddressLine1': 'North Fountain Avenue',
#    'StateOrProvince': 'Ohio',
#    'Postcode': '45502',
#    'CountryID': 2,
#    'Latitude': 39.92546493791434,
#    'Longitude': -83.81041596831312,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 559612,
#     'ConnectionTypeID': 1,
#     'StatusTypeID': 50,
#     'Quantity': 2,
#     'Comments': 'Greenspot APP required '}],
#   'NumberOfPoints': 2,
#   'GeneralComments': 'Covered parking garage. ',
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-07-12T08:34:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2024-07-07T16:54:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2024-07-14T06:01:00Z',
#   'ID': 300507,
#   'UUID': 'CCA304BD-54A9-41DD-8114-F2AB29A1AF85',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 1,
#   'UsageCost': 'Free for Hotel Guests',
#   'AddressInfo': {'ID': 300894,
#    'Title': 'Hyatt Place Huntsville / Research Park / Redstone',
#    'AddressLine1': '6860 Governors West NW',
#    'Town': 'Huntsville',
#    'StateOrProvince': 'AL',
#    'Postcode': '35806',
#    'CountryID': 2,
#    'Latitude': 34.71752296455128,
#    'Longitude': -86.67701206998674,
#    'RelatedURL': 'https://www.hyatt.com/hyatt-place/en-US/hsvzh-hyatt-place-huntsville-research-park-redstone',
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 559495,
#     'ConnectionTypeID': 27,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 48,
#     'Voltage': 208,
#     'PowerKW': 11,
#     'CurrentTypeID': 10,
#     'Quantity': 2}],
#   'NumberOfPoints': 2,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-07-14T06:01:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2024-07-06T21:58:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2024-08-27T15:02:00Z',
#   'ID': 300501,
#   'UUID': 'B1F4D8F5-2608-4522-804D-1BFF5FDBF496',
#   'DataProviderID': 1,
#   'OperatorID': 5,
#   'UsageTypeID': 4,
#   'UsageCost': '$0.35/kWh',
#   'AddressInfo': {'ID': 300888,
#    'Title': 'ChargePoint - Newton Service Plaza I-95 Southbound',
#    'AddressLine1': '6 MA-128',
#    'Town': 'Newton',
#    'StateOrProvince': 'MA',
#    'Postcode': '02462',
#    'CountryID': 2,
#    'Latitude': 42.33069641243446,
#    'Longitude': -71.25476050220476,
#    'ContactTelephone1': '888-758-4389',
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 559486,
#     'ConnectionTypeID': 32,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 62.5,
#     'CurrentTypeID': 30,
#     'Quantity': 2},
#    {'ID': 572425,
#     'ConnectionTypeID': 2,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 50,
#     'CurrentTypeID': 30,
#     'Quantity': 2}],
#   'NumberOfPoints': 2,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-08-27T15:02:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2024-07-06T21:30:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2024-07-09T21:29:00Z',
#   'ID': 300499,
#   'UUID': '6CF3DE71-4F5B-4DA4-9BAE-4A85B15BB01D',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 1,
#   'UsageCost': '$0.35/kWh',
#   'AddressInfo': {'ID': 300886,
#    'Title': 'Autel - Framingham Rest Stop Westbound',
#    'AddressLine1': '114 Massachusetts Turnpike',
#    'Town': 'Framingham',
#    'StateOrProvince': 'MA',
#    'Postcode': '01701',
#    'CountryID': 2,
#    'Latitude': 42.311933799521114,
#    'Longitude': -71.42901566704325,
#    'ContactTelephone1': '844-765-0150',
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 559484,
#     'ConnectionTypeID': 32,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 60,
#     'CurrentTypeID': 30,
#     'Quantity': 2}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-07-09T21:29:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2024-07-06T21:25:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2024-07-08T03:19:00Z',
#   'ID': 300452,
#   'UUID': 'D71BAB30-A266-45C3-8563-818A960D3A2B',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 4,
#   'UsageCost': '0.35',
#   'AddressInfo': {'ID': 300839,
#    'Title': 'West Grand River Avenue',
#    'AddressLine1': 'West Grand River Avenue',
#    'Town': 'Grand Ledge',
#    'StateOrProvince': 'Michigan',
#    'Postcode': '48837',
#    'CountryID': 2,
#    'Latitude': 42.78655467993087,
#    'Longitude': -84.67700799361035,
#    'AccessComments': 'Shared chargers',
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 559419,
#     'ConnectionTypeID': 33,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 350,
#     'CurrentTypeID': 30,
#     'Quantity': 4,
#     'Comments': 'Opened 7/4/24'}],
#   'NumberOfPoints': 4,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-07-08T03:19:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2024-07-04T23:02:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2024-07-08T03:19:00Z',
#   'ID': 300414,
#   'UUID': 'D69FAF52-5848-4FC0-9CFE-579FED6907DA',
#   'DataProviderID': 1,
#   'OperatorID': 5,
#   'UsageTypeID': 1,
#   'AddressInfo': {'ID': 300801,
#    'Title': 'Jackson EMC Neese',
#    'AddressLine1': '85 Spratlin Mill Rd',
#    'StateOrProvince': 'Hull',
#    'Postcode': '30646',
#    'CountryID': 2,
#    'Latitude': 34.062257296885406,
#    'Longitude': -83.27364667601528,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 559364,
#     'ConnectionTypeID': 32,
#     'StatusTypeID': 50,
#     'CurrentTypeID': 30,
#     'Quantity': 1},
#    {'ID': 559365, 'ConnectionTypeID': 2, 'StatusTypeID': 50, 'Quantity': 1}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-07-08T03:19:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2024-07-02T18:00:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2024-07-08T03:19:00Z',
#   'ID': 300382,
#   'UUID': '2AC71C2F-D972-4188-B9CF-77A525CB8B09',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 1,
#   'UsageCost': 'free with parking payment',
#   'AddressInfo': {'ID': 300769,
#    'Title': 'Laidley Garage',
#    'AddressLine1': '501 Virginia St',
#    'Town': 'Charleston',
#    'StateOrProvince': 'WV',
#    'Postcode': '25301',
#    'CountryID': 2,
#    'Latitude': 38.35047412494575,
#    'Longitude': -81.6381696718033,
#    'AccessComments': 'Parking $1/hr 7a-5p M-F, free nights and weekends',
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 559328,
#     'ConnectionTypeID': 1,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'PowerKW': 7.8,
#     'CurrentTypeID': 10,
#     'Quantity': 2}],
#   'NumberOfPoints': 2,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-07-08T03:19:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2024-07-01T12:43:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2024-07-08T03:19:00Z',
#   'ID': 300366,
#   'UUID': '1C5083D4-CA8F-433C-AD7D-454964B21CA2',
#   'DataProviderID': 1,
#   'OperatorID': 59,
#   'UsageTypeID': 5,
#   'UsageCost': '$0.44 kWh',
#   'AddressInfo': {'ID': 300753,
#    'Title': 'Woody Anderson Ford',
#    'AddressLine1': '2500 Jordan Ln NW',
#    'Town': 'Huntsville',
#    'StateOrProvince': 'AL',
#    'Postcode': '35816',
#    'CountryID': 2,
#    'Latitude': 34.7572939937118,
#    'Longitude': -86.63826593883144,
#    'ContactTelephone1': '+1 (256) 513-4597',
#    'AccessComments': 'South end of lot.  Available when dealership open.  Trailer friendly',
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 559089,
#     'ConnectionTypeID': 32,
#     'StatusTypeID': 50,
#     'CurrentTypeID': 30,
#     'Quantity': 2,
#     'Comments': 'Available when dealership open'}],
#   'NumberOfPoints': 2,
#   'GeneralComments': 'Available when dealership open',
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-07-08T03:19:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2024-06-29T18:29:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2024-07-08T03:19:00Z',
#   'ID': 300302,
#   'UUID': '727E8751-2ACA-4C9E-BEDF-727B720600C8',
#   'DataProviderID': 1,
#   'OperatorID': 3696,
#   'UsageTypeID': 5,
#   'UsageCost': '$0.42/kWh',
#   'AddressInfo': {'ID': 300689,
#    'Title': 'Long-Lewis Ford',
#    'AddressLine1': '2800 SR-13 ',
#    'Town': 'Muscle Shoals',
#    'StateOrProvince': 'AL',
#    'Postcode': '35661',
#    'CountryID': 2,
#    'Latitude': 34.73526493606231,
#    'Longitude': -87.66802120344545,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 558893,
#     'ConnectionTypeID': 33,
#     'StatusTypeID': 50,
#     'CurrentTypeID': 30,
#     'Quantity': 2}],
#   'NumberOfPoints': 2,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-07-08T03:19:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2024-06-28T17:30:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2024-06-24T05:39:00Z',
#   'ID': 300093,
#   'UUID': 'D3DCE84B-5982-4BC9-9122-F797CAE500B3',
#   'DataProviderID': 1,
#   'OperatorID': 3318,
#   'UsageTypeID': 1,
#   'UsageCost': '0.56',
#   'AddressInfo': {'ID': 300480,
#    'Title': 'Meijer 125 (Fort Wayne, IN)',
#    'AddressLine1': '5909 Illinois Rd',
#    'Town': 'Fort Wayne',
#    'StateOrProvince': 'IN',
#    'Postcode': '46804',
#    'CountryID': 2,
#    'Latitude': 41.0729573630303,
#    'Longitude': -85.21817377252916,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 556443,
#     'ConnectionTypeID': 32,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 350,
#     'CurrentTypeID': 30,
#     'Quantity': 6}],
#   'NumberOfPoints': 6,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-06-24T05:39:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2024-06-19T16:03:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2024-07-25T17:28:00Z',
#   'ID': 300012,
#   'UUID': 'E3EB53EE-9376-413C-8AD6-661D28923F89',
#   'DataProviderID': 1,
#   'OperatorID': 3580,
#   'UsageTypeID': 5,
#   'UsageCost': '$0.49/kWh',
#   'AddressInfo': {'ID': 300399,
#    'Title': 'ReCharge Alaska Charging Station',
#    'AddressLine1': '665 E. 33rd Ave',
#    'Town': 'Anchorage',
#    'StateOrProvince': 'Alaska',
#    'Postcode': '99503',
#    'CountryID': 2,
#    'Latitude': 61.19150707516931,
#    'Longitude': -149.8700895113967,
#    'ContactTelephone1': '7208331479',
#    'RelatedURL': 'https://www.rechargealaska.net/',
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 555642,
#     'ConnectionTypeID': 32,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'Amps': 200,
#     'Voltage': 920,
#     'PowerKW': 75,
#     'CurrentTypeID': 30,
#     'Quantity': 2},
#    {'ID': 555643,
#     'ConnectionTypeID': 2,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'Amps': 125,
#     'Voltage': 920,
#     'PowerKW': 50,
#     'CurrentTypeID': 30,
#     'Quantity': 2}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-07-25T17:28:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2024-06-15T17:20:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2024-06-17T12:53:00Z',
#   'ID': 299984,
#   'UUID': '374D63BC-FA9B-479D-B263-C06C3AB3661B',
#   'DataProviderID': 1,
#   'OperatorID': 3619,
#   'UsageTypeID': 1,
#   'UsageCost': '$0.35 per kWh',
#   'AddressInfo': {'ID': 300371,
#    'Title': 'The Vintage at the Grove',
#    'AddressLine1': '1500 Horizon Way',
#    'Town': 'Manchester',
#    'StateOrProvince': 'CT',
#    'Postcode': '06042',
#    'CountryID': 2,
#    'Latitude': 41.801168528298575,
#    'Longitude': -72.54248938937177,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 555425,
#     'ConnectionTypeID': 1,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 50,
#     'Voltage': 230,
#     'PowerKW': 11.5,
#     'CurrentTypeID': 10,
#     'Quantity': 2},
#    {'ID': 556065,
#     'ConnectionTypeID': 1,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 50,
#     'Voltage': 230,
#     'PowerKW': 11.5,
#     'CurrentTypeID': 10,
#     'Quantity': 2},
#    {'ID': 556066,
#     'ConnectionTypeID': 1,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 50,
#     'Voltage': 230,
#     'PowerKW': 11.5,
#     'CurrentTypeID': 10,
#     'Quantity': 2}],
#   'NumberOfPoints': 6,
#   'GeneralComments': 'Three separate instances of paired chargers and spots. Under one location in AmpUp map',
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-06-17T12:53:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2024-06-14T18:49:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2024-06-14T07:16:00Z',
#   'ID': 299978,
#   'UUID': '07545C50-B4F4-4FB6-9CE1-E558641A50C0',
#   'DataProviderID': 1,
#   'OperatorID': 5,
#   'UsageTypeID': 4,
#   'UsageCost': '$2',
#   'AddressInfo': {'ID': 300365,
#    'Title': 'Crater Lake Highway',
#    'AddressLine1': 'Crater Lake Highway',
#    'Town': 'Medford',
#    'StateOrProvince': 'Oregon',
#    'Postcode': '97501',
#    'CountryID': 2,
#    'Latitude': 42.347739941644136,
#    'Longitude': -122.87888932044652,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 555412,
#     'ConnectionTypeID': 1,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'PowerKW': 7.4,
#     'Quantity': 4}],
#   'NumberOfPoints': 4,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-06-14T07:16:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2024-06-14T07:16:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2024-06-24T05:39:00Z',
#   'ID': 299886,
#   'UUID': 'B366F957-43AD-4ABC-BFF2-8E4CA353442B',
#   'DataProviderID': 1,
#   'OperatorID': 3621,
#   'UsageTypeID': 4,
#   'UsageCost': '1.50 / hr for the first 4 hours, 5.00 / hr for subsequent time.  price set by Hershey Lodge. discounts from chargelab due to charger running below their configured speed of 11kw.',
#   'AddressInfo': {'ID': 300273,
#    'Title': 'Hershey Lodge ',
#    'AddressLine1': '325 University Drive',
#    'Town': 'Hershey',
#    'StateOrProvince': 'Pennsylvania',
#    'Postcode': '17033',
#    'CountryID': 2,
#    'Latitude': 40.2694308494888,
#    'Longitude': -76.67727713186478,
#    'AccessComments': 'Charger is located at the end of a dead end parking lot behind the main lobby of the Hershey Lodge.  Caution advised to larger vehicles, as multipoint turns may be necessary to get into the spot.',
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 554306,
#     'ConnectionTypeID': 1,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'PowerKW': 6,
#     'CurrentTypeID': 10,
#     'Quantity': 2,
#     'Comments': 'charge lab shows this charger has 11kw, but actually delivers 6kw.  fortunately chargelab discounts the price due to this difference.'}],
#   'NumberOfPoints': 2,
#   'GeneralComments': '',
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-06-24T05:39:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2024-06-10T16:36:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2024-06-10T14:22:00Z',
#   'ID': 299883,
#   'UUID': 'B77C7D66-1BD0-47FB-802D-59A3D58DD90E',
#   'DataProviderID': 1,
#   'OperatorID': 3788,
#   'UsageTypeID': 1,
#   'AddressInfo': {'ID': 300270,
#    'Title': 'ARCO',
#    'AddressLine1': '2979 Market St NE',
#    'Town': 'Salem',
#    'StateOrProvince': 'OR',
#    'Postcode': '97301',
#    'CountryID': 2,
#    'Latitude': 44.95060518861868,
#    'Longitude': -122.99821784810624,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 554302,
#     'ConnectionTypeID': 2,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 100,
#     'CurrentTypeID': 30,
#     'Quantity': 1},
#    {'ID': 554303,
#     'ConnectionTypeID': 32,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 150,
#     'CurrentTypeID': 30,
#     'Quantity': 5}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-06-10T14:22:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2024-06-10T14:22:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2024-06-09T11:48:00Z',
#   'ID': 299869,
#   'UUID': '0B138E64-7A3A-4852-B118-C39E939D593A',
#   'DataProviderID': 1,
#   'OperatorID': 3534,
#   'UsageTypeID': 1,
#   'AddressInfo': {'ID': 300256,
#    'Title': 'Sisters Inn & Suites',
#    'AddressLine1': '625 N Arrowleaf Trail',
#    'Town': 'Sisters',
#    'StateOrProvince': 'Oregon',
#    'Postcode': '97759',
#    'CountryID': 2,
#    'Latitude': 44.29607803775141,
#    'Longitude': -121.56114917248375,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 554023,
#     'ConnectionTypeID': 27,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 250,
#     'CurrentTypeID': 30,
#     'Quantity': 8}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-06-09T11:48:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2024-06-09T11:48:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2024-06-08T13:03:00Z',
#   'ID': 299855,
#   'UUID': 'B3361B3A-A245-4519-8CE0-DA771F34F1D8',
#   'DataProviderID': 1,
#   'OperatorID': 3534,
#   'UsageTypeID': 1,
#   'AddressInfo': {'ID': 300242,
#    'Title': 'Grocery Outlet - Supercharger',
#    'AddressLine1': '4315 S 6th St',
#    'Town': 'Klamath Falls',
#    'StateOrProvince': 'OR',
#    'Postcode': '97603',
#    'CountryID': 2,
#    'Latitude': 42.206913,
#    'Longitude': -121.735788,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 553668,
#     'ConnectionTypeID': 27,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 250,
#     'CurrentTypeID': 30,
#     'Quantity': 8}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-06-08T13:03:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2024-06-08T13:03:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2024-06-07T13:30:00Z',
#   'ID': 299834,
#   'UUID': '7D09771D-08FA-47C9-9A7A-85E12ABB524C',
#   'DataProviderID': 1,
#   'OperatorID': 3318,
#   'UsageTypeID': 1,
#   'AddressInfo': {'ID': 300221,
#    'Title': 'Fred Meyers',
#    'AddressLine1': '30300 SW Boones Ferry Rd',
#    'Town': 'Wilsonville',
#    'StateOrProvince': 'OR',
#    'Postcode': '97070',
#    'CountryID': 2,
#    'Latitude': 45.29992,
#    'Longitude': -122.77226,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 552987,
#     'ConnectionTypeID': 32,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 350,
#     'CurrentTypeID': 30,
#     'Quantity': 4}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-06-07T13:30:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2024-06-07T13:30:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2024-06-24T05:39:00Z',
#   'ID': 299831,
#   'UUID': 'E88CE172-00FE-40F4-9178-599D2DAE60F1',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 6,
#   'UsageCost': 'Free after park entrance fee',
#   'AddressInfo': {'ID': 300218,
#    'Title': 'Taylor Mountain Regional Park',
#    'AddressLine1': '3870-3400 Petaluma Hill Rd.',
#    'Town': ' Santa Rosa',
#    'StateOrProvince': 'CA ',
#    'Postcode': '95404',
#    'CountryID': 2,
#    'Latitude': 38.40363417947805,
#    'Longitude': -122.69724346741012,
#    'AccessComments': 'Park entrance fee at pay station',
#    'RelatedURL': 'https://parks.sonomacounty.ca.gov/sonoma-county-boosts-green-energy-infrastructure-with-new-mobile-solar-powered-ev-charging-stations',
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 552973,
#     'ConnectionTypeID': 1,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 20,
#     'Voltage': 240,
#     'PowerKW': 5,
#     'CurrentTypeID': 10,
#     'Quantity': 2,
#     'Comments': 'Portable solar powered EV charging station. Free after paying park entrance fee. 30 kWh battery backup. Emergency services access available.'}],
#   'NumberOfPoints': 2,
#   'GeneralComments': 'Portable solar powered EV charging station. Free after paying park entrance fee. 30 kWh battery backup. Emergency services access available.',
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-06-24T05:39:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2024-06-06T22:36:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2024-06-06T13:34:00Z',
#   'ID': 299828,
#   'UUID': '83E702F6-184F-447B-99A2-29081DCD31C4',
#   'DataProviderID': 1,
#   'OperatorID': 3534,
#   'UsageTypeID': 1,
#   'AddressInfo': {'ID': 300215,
#    'Title': 'Country Club Gate Center - Supercharger',
#    'AddressLine1': '200 Country Club Gate Center',
#    'Town': 'Pacific Grove',
#    'StateOrProvince': 'CA',
#    'Postcode': '93950',
#    'CountryID': 2,
#    'Latitude': 36.6079673426384,
#    'Longitude': -121.9250272219867,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 552966,
#     'ConnectionTypeID': 27,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 250,
#     'CurrentTypeID': 30,
#     'Quantity': 12}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-06-06T13:34:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2024-06-06T13:34:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2024-06-06T11:24:00Z',
#   'ID': 299824,
#   'UUID': '834F74FB-C59E-411D-8119-E621A3385998',
#   'DataProviderID': 1,
#   'OperatorID': 3389,
#   'UsageTypeID': 1,
#   'AddressInfo': {'ID': 300211,
#    'Title': 'Eastlake Village Center',
#    'AddressLine1': '2220 Otay Lakes Rd',
#    'Town': 'Chula Vista',
#    'StateOrProvince': 'CA',
#    'Postcode': '91915',
#    'CountryID': 2,
#    'Latitude': 32.64576466795185,
#    'Longitude': -116.96819867066247,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 552961,
#     'ConnectionTypeID': 2,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 100,
#     'CurrentTypeID': 30,
#     'Quantity': 1},
#    {'ID': 552962,
#     'ConnectionTypeID': 32,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 150,
#     'CurrentTypeID': 30,
#     'Quantity': 3}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-06-06T11:24:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2024-06-06T11:24:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2024-06-24T05:39:00Z',
#   'ID': 299813,
#   'UUID': '69123C8D-85CB-40A7-9E9C-E3734EF3844C',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 300200,
#    'Title': 'Nyack Road',
#    'AddressLine1': 'Nyack Road',
#    'Town': 'Emigrant Gap',
#    'StateOrProvince': 'CA',
#    'Postcode': '95715',
#    'CountryID': 2,
#    'Latitude': 39.29191930389058,
#    'Longitude': -120.67845745375394,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 552932,
#     'ConnectionTypeID': 32,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 50,
#     'CurrentTypeID': 30,
#     'Quantity': 2}],
#   'NumberOfPoints': 2,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-06-24T05:39:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2024-06-06T06:10:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2024-06-06T09:08:00Z',
#   'ID': 299812,
#   'UUID': 'FDCB64A5-5B47-47E5-B403-1A4D8A364DC8',
#   'DataProviderID': 35,
#   'DataProvidersReference': '0',
#   'OperatorID': 3789,
#   'AddressInfo': {'ID': 300199,
#    'Title': 'Plaid Pantry PowerNode Charging Station',
#    'AddressLine1': '6060 NE Columbia Blvd',
#    'Town': 'Portland',
#    'Postcode': '97218',
#    'CountryID': 2,
#    'Latitude': 45.5682999,
#    'Longitude': -122.5996726,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 552930,
#     'ConnectionTypeID': 32,
#     'Reference': '1',
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'Amps': 300,
#     'Voltage': 1000,
#     'PowerKW': 150,
#     'CurrentTypeID': 30,
#     'Quantity': 1},
#    {'ID': 552931,
#     'ConnectionTypeID': 2,
#     'Reference': '2',
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'Amps': 200,
#     'Voltage': 500,
#     'PowerKW': 100,
#     'CurrentTypeID': 30,
#     'Quantity': 1}],
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-06-06T09:08:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2024-06-06T05:16:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2024-06-05T22:10:00Z',
#   'ID': 299810,
#   'UUID': 'E26F5C6A-A0C3-4CA4-81E0-9F5042AD4456',
#   'DataProviderID': 1,
#   'OperatorID': 3697,
#   'UsageTypeID': 1,
#   'AddressInfo': {'ID': 300197,
#    'Title': '7-Eleven',
#    'AddressLine1': '1670 E Main St',
#    'Town': 'Woodland',
#    'StateOrProvince': 'CA',
#    'Postcode': '95776',
#    'CountryID': 2,
#    'Latitude': 38.67694661727603,
#    'Longitude': -121.74381135300567,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 552927,
#     'ConnectionTypeID': 2,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 180,
#     'CurrentTypeID': 30,
#     'Quantity': 1},
#    {'ID': 552928,
#     'ConnectionTypeID': 32,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 180,
#     'CurrentTypeID': 30,
#     'Quantity': 3}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-06-05T22:10:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2024-06-05T22:10:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2024-06-05T22:05:00Z',
#   'ID': 299809,
#   'UUID': 'DEB15C81-038C-416E-9DC3-863788BED1DD',
#   'DataProviderID': 1,
#   'OperatorID': 3697,
#   'UsageTypeID': 1,
#   'AddressInfo': {'ID': 300196,
#    'Title': '7-Eleven',
#    'AddressLine1': '1808 N Broadway',
#    'Town': 'Santa Maria',
#    'StateOrProvince': 'CA',
#    'Postcode': '93454',
#    'CountryID': 2,
#    'Latitude': 34.972608028643506,
#    'Longitude': -120.43545269627003,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 552925,
#     'ConnectionTypeID': 2,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 180,
#     'CurrentTypeID': 30,
#     'Quantity': 1},
#    {'ID': 552926,
# ...
#   'ID': 294442,
#   'UUID': 'C2E1335A-3FBC-496A-B84E-F8B03EE1C5C2',
#   'DataProviderID': 2,
#   'DataProvidersReference': '325352',
#   'OperatorID': 3372,
#   'UsageTypeID': 1,
#   'AddressInfo': {'ID': 294829,
#    'Title': 'GM - ED MARTIN CADILLAC',
#    'AddressLine1': '5400 S Scatterfield Road',
#    'Town': 'Anderson',
#    'StateOrProvince': 'IN',
#    'Postcode': '46013',
#    'CountryID': 2,
#    'Latitude': 40.060283,
#    'Longitude': -85.651274,
#    'ContactTelephone1': '866-816-7584',
#    'AccessComments': '',
#    'RelatedURL': 'http://evconnect.com/',
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 525798,
#     'ConnectionTypeID': 32,
#     'LevelID': 3,
#     'PowerKW': 50,
#     'CurrentTypeID': 30,
#     'Quantity': 1,
#     'Comments': 'kW power is an estimate based on the connection type'}],
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-02-20T10:16:00Z',
#   'DataQualityLevel': 3,
#   'DateCreated': '2024-02-20T10:16:00Z',
#   'SubmissionStatusTypeID': 100},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2024-02-20T10:16:00Z',
#   'ID': 294441,
#   'UUID': '77D6196C-A885-4D40-B9DD-A0CB1D27BFFB',
#   'DataProviderID': 2,
#   'DataProvidersReference': '327527',
#   'OperatorID': 5,
#   'UsageTypeID': 1,
#   'AddressInfo': {'ID': 294828,
#    'Title': 'BVCOA CHARGER BVCAC1',
#    'AddressLine1': '1775 Yaupon Ave',
#    'Town': 'Boulder',
#    'StateOrProvince': 'CO',
#    'Postcode': '80304',
#    'CountryID': 2,
#    'Latitude': 40.059421,
#    'Longitude': -105.275366,
#    'ContactTelephone1': '888-758-4389',
#    'AccessComments': '24 hours daily',
#    'RelatedURL': 'http://www.chargepoint.com/',
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 525797,
#     'ConnectionTypeID': 1,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 3.7,
#     'CurrentTypeID': 10,
#     'Quantity': 2,
#     'Comments': 'kW power is an estimate based on the connection type'}],
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-02-20T10:16:00Z',
#   'DataQualityLevel': 3,
#   'DateCreated': '2024-02-20T10:16:00Z',
#   'SubmissionStatusTypeID': 100},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2024-02-20T10:16:00Z',
#   'ID': 294440,
#   'UUID': 'F0A261C8-14AF-44FB-9136-FADDFD3BBB13',
#   'DataProviderID': 2,
#   'DataProvidersReference': '326682',
#   'UsageTypeID': 5,
#   'AddressInfo': {'ID': 294827,
#    'Title': 'Wheeling Subaru Volkswagen',
#    'AddressLine1': 'US-40 E',
#    'Town': 'Wheeling',
#    'StateOrProvince': 'WV',
#    'Postcode': '26003',
#    'CountryID': 2,
#    'Latitude': 40.0490511897617,
#    'Longitude': -80.6422709369795,
#    'ContactTelephone1': '304-242-7313',
#    'AccessComments': '9am-7pm M-Thu, 10am-6pm F, 9am-4pm Sat\r\nPublic - Credit card at all times',
#    'RelatedURL': '',
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 525796,
#     'ConnectionTypeID': 1,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 3.7,
#     'CurrentTypeID': 10,
#     'Quantity': 1,
#     'Comments': 'kW power is an estimate based on the connection type'}],
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-02-20T10:16:00Z',
#   'DataQualityLevel': 3,
#   'DateCreated': '2024-02-20T10:16:00Z',
#   'SubmissionStatusTypeID': 100},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2024-02-20T10:15:00Z',
#   'ID': 294439,
#   'UUID': 'EA7AA139-C863-4F85-B666-95EF56ED2B9E',
#   'DataProviderID': 2,
#   'DataProvidersReference': '322755',
#   'OperatorID': 9,
#   'UsageTypeID': 1,
#   'AddressInfo': {'ID': 294826,
#    'Title': "Coughlin Ford Heath DCFC's",
#    'AddressLine1': '500 Hebron Road',
#    'Town': 'Newark',
#    'StateOrProvince': 'OH',
#    'Postcode': '43056',
#    'CountryID': 2,
#    'Latitude': 40.03840738127086,
#    'Longitude': -82.42761604003167,
#    'ContactTelephone1': '888-998-2546',
#    'AccessComments': '24 hours daily',
#    'RelatedURL': 'http://www.blinkcharging.com/',
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 525795,
#     'ConnectionTypeID': 32,
#     'LevelID': 3,
#     'PowerKW': 50,
#     'CurrentTypeID': 30,
#     'Quantity': 3,
#     'Comments': 'kW power is an estimate based on the connection type'}],
#   'DatePlanned': '2023-12-15T00:00:00Z',
#   'StatusTypeID': 30,
#   'DateLastStatusUpdate': '2024-02-20T10:15:00Z',
#   'DataQualityLevel': 3,
#   'DateCreated': '2024-02-20T10:15:00Z',
#   'SubmissionStatusTypeID': 100},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2024-02-20T10:15:00Z',
#   'ID': 294438,
#   'UUID': '856E113B-7848-474E-BF49-BC087C651ED2',
#   'DataProviderID': 2,
#   'DataProvidersReference': '306361',
#   'OperatorID': 5,
#   'UsageTypeID': 1,
#   'AddressInfo': {'ID': 294825,
#    'Title': 'CENTERPOINT NOB 1',
#    'AddressLine1': '16222 Allisonville Rd',
#    'Town': 'Noblesville',
#    'StateOrProvince': 'IN',
#    'Postcode': '46060',
#    'CountryID': 2,
#    'Latitude': 40.026348,
#    'Longitude': -86.013341,
#    'ContactTelephone1': '888-758-4389',
#    'AccessComments': '24 hours daily',
#    'RelatedURL': 'http://www.chargepoint.com/',
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 525794,
#     'ConnectionTypeID': 1,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 3.7,
#     'CurrentTypeID': 10,
#     'Quantity': 1,
#     'Comments': 'kW power is an estimate based on the connection type'}],
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-02-20T10:15:00Z',
#   'DataQualityLevel': 3,
#   'DateCreated': '2024-02-20T10:15:00Z',
#   'SubmissionStatusTypeID': 100},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2024-02-20T10:15:00Z',
#   'ID': 294437,
#   'UUID': '623FD73C-D88D-4437-BAB3-4D3939056FF7',
#   'DataProviderID': 2,
#   'DataProvidersReference': '328641',
#   'OperatorID': 9,
#   'UsageTypeID': 1,
#   'AddressInfo': {'ID': 294824,
#    'Title': '24 Hour Fitness',
#    'AddressLine1': '851 U.S. 287',
#    'Town': 'Lafayette',
#    'StateOrProvince': 'CO',
#    'Postcode': '80026',
#    'CountryID': 2,
#    'Latitude': 40.0094356,
#    'Longitude': -105.1052399,
#    'ContactTelephone1': '888-998-2546',
#    'AccessComments': '24 hours daily',
#    'RelatedURL': 'http://www.blinkcharging.com/',
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 525793,
#     'ConnectionTypeID': 1,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 3.7,
#     'CurrentTypeID': 10,
#     'Quantity': 4,
#     'Comments': 'kW power is an estimate based on the connection type'}],
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-02-20T10:15:00Z',
#   'DataQualityLevel': 3,
#   'DateCreated': '2024-02-20T10:15:00Z',
#   'SubmissionStatusTypeID': 100},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2024-02-20T10:15:00Z',
#   'ID': 294436,
#   'UUID': '49AB4CE2-2AB6-455D-8F77-99069B14C8D8',
#   'DataProviderID': 2,
#   'DataProvidersReference': '323704',
#   'OperatorID': 3389,
#   'UsageTypeID': 1,
#   'AddressInfo': {'ID': 294823,
#    'Title': 'Solar Hotel',
#    'AddressLine1': '240 Hartman Bridge Rd',
#    'Town': 'Manheim',
#    'StateOrProvince': 'PA',
#    'Postcode': '17572',
#    'CountryID': 2,
#    'Latitude': 39.99998,
#    'Longitude': -76.18514,
#    'ContactTelephone1': '717-687-8635',
#    'AccessComments': '24 hours daily',
#    'RelatedURL': 'http://evgateway.com/',
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 525792,
#     'ConnectionTypeID': 1,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 3.7,
#     'CurrentTypeID': 10,
#     'Quantity': 8,
#     'Comments': 'kW power is an estimate based on the connection type'}],
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-02-20T10:15:00Z',
#   'DataQualityLevel': 3,
#   'DateCreated': '2024-02-20T10:15:00Z',
#   'SubmissionStatusTypeID': 100},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2024-02-20T10:15:00Z',
#   'ID': 294435,
#   'UUID': '65FD14CB-BAD5-452C-A3DA-E81009A3B0CD',
#   'DataProviderID': 2,
#   'DataProvidersReference': '327135',
#   'OperatorID': 9,
#   'UsageTypeID': 1,
#   'AddressInfo': {'ID': 294822,
#    'Title': 'Quarry Trails',
#    'AddressLine1': '2130 Quarry Trails Drive',
#    'Town': 'Columbus',
#    'StateOrProvince': 'OH',
#    'Postcode': '43228',
#    'CountryID': 2,
#    'Latitude': 39.99869239874049,
#    'Longitude': -83.08291364417703,
#    'ContactTelephone1': '888-998-2546',
#    'AccessComments': '24 hours daily',
#    'RelatedURL': 'http://www.blinkcharging.com/',
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 525791,
#     'ConnectionTypeID': 1,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 3.7,
#     'CurrentTypeID': 10,
#     'Quantity': 1,
#     'Comments': 'kW power is an estimate based on the connection type'}],
#   'DatePlanned': '2024-02-01T00:00:00Z',
#   'StatusTypeID': 30,
#   'DateLastStatusUpdate': '2024-02-20T10:15:00Z',
#   'DataQualityLevel': 3,
#   'DateCreated': '2024-02-20T10:15:00Z',
#   'SubmissionStatusTypeID': 100},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2024-02-20T10:15:00Z',
#   'ID': 294434,
#   'UUID': '0A1C596B-99FF-4171-B3CC-896781505384',
#   'DataProviderID': 2,
#   'DataProvidersReference': '323792',
#   'OperatorID': 9,
#   'UsageTypeID': 1,
#   'AddressInfo': {'ID': 294821,
#    'Title': 'Lotano Speedy & Sons',
#    'AddressLine1': '1415 Hooper Avenue',
#    'Town': 'Toms River',
#    'StateOrProvince': 'NJ',
#    'Postcode': '08753',
#    'CountryID': 2,
#    'Latitude': 39.99253946393471,
#    'Longitude': -74.17328954232919,
#    'ContactTelephone1': '888-998-2546',
#    'AccessComments': '24 hours daily',
#    'RelatedURL': 'http://www.blinkcharging.com/',
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 525790,
#     'ConnectionTypeID': 1,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 3.7,
#     'CurrentTypeID': 10,
#     'Quantity': 1,
#     'Comments': 'kW power is an estimate based on the connection type'}],
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-02-20T10:15:00Z',
#   'DataQualityLevel': 3,
#   'DateCreated': '2024-02-20T10:15:00Z',
#   'SubmissionStatusTypeID': 100},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2024-02-20T10:15:00Z',
#   'ID': 294433,
#   'UUID': 'DCAF597A-CA0B-4290-9FC0-3EAB0D2C7BBB',
#   'DataProviderID': 2,
#   'DataProvidersReference': '323277',
#   'OperatorID': 3346,
#   'UsageTypeID': 5,
#   'AddressInfo': {'ID': 294820,
#    'Title': 'Go Share High St Mobility Hub',
#    'AddressLine1': '1161 N High St',
#    'Town': 'Columbus',
#    'StateOrProvince': 'OH',
#    'Postcode': '43201',
#    'CountryID': 2,
#    'Latitude': 39.9862646868455,
#    'Longitude': -83.0057749196317,
#    'ContactTelephone1': '888-272-6618',
#    'AccessComments': '24 hours daily\r\nPublic - Credit card at all times',
#    'RelatedURL': 'https://www.noodoe.com',
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 525789,
#     'ConnectionTypeID': 1,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 3.7,
#     'CurrentTypeID': 10,
#     'Quantity': 4,
#     'Comments': 'kW power is an estimate based on the connection type'}],
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-02-20T10:15:00Z',
#   'DataQualityLevel': 3,
#   'DateCreated': '2024-02-20T10:15:00Z',
#   'SubmissionStatusTypeID': 100},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2024-02-20T10:15:00Z',
#   'ID': 294432,
#   'UUID': 'CBFF4C31-C8DE-400C-B1B7-431B09385DDC',
#   'DataProviderID': 2,
#   'DataProvidersReference': '322150',
#   'UsageTypeID': 2,
#   'AddressInfo': {'ID': 294819,
#    'Title': 'Iconergy Boulder',
#    'AddressLine1': '5277 Manhattan Cir',
#    'Town': 'Boulder',
#    'StateOrProvince': 'CO',
#    'Postcode': '80303',
#    'CountryID': 2,
#    'Latitude': 39.98507,
#    'Longitude': -105.22944,
#    'ContactTelephone1': '303-942-1713',
#    'AccessComments': '24 hours daily',
#    'RelatedURL': '',
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 525788,
#     'ConnectionTypeID': 1,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 3.7,
#     'CurrentTypeID': 10,
#     'Quantity': 4,
#     'Comments': 'kW power is an estimate based on the connection type'}],
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-02-20T10:15:00Z',
#   'DataQualityLevel': 3,
#   'DateCreated': '2024-02-20T10:15:00Z',
#   'SubmissionStatusTypeID': 100},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2024-02-20T10:15:00Z',
#   'ID': 294431,
#   'UUID': 'F40603D1-49F3-41E4-B8A1-827A8F0E77F1',
#   'DataProviderID': 2,
#   'DataProvidersReference': '324397',
#   'OperatorID': 5,
#   'UsageTypeID': 1,
#   'AddressInfo': {'ID': 294818,
#    'Title': 'AAA MID STATES AAA MID STATES1',
#    'AddressLine1': '2840 Eastern Blvd',
#    'Town': 'York',
#    'StateOrProvince': 'PA',
#    'Postcode': '17402',
#    'CountryID': 2,
#    'Latitude': 39.972543,
#    'Longitude': -76.671386,
#    'ContactTelephone1': '888-758-4389',
#    'AccessComments': '24 hours daily',
#    'RelatedURL': 'http://www.chargepoint.com/',
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 525787,
#     'ConnectionTypeID': 1,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 3.7,
#     'CurrentTypeID': 10,
#     'Quantity': 2,
#     'Comments': 'kW power is an estimate based on the connection type'}],
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-02-20T10:15:00Z',
#   'DataQualityLevel': 3,
#   'DateCreated': '2024-02-20T10:15:00Z',
#   'SubmissionStatusTypeID': 100},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2024-02-20T10:15:00Z',
#   'ID': 294430,
#   'UUID': 'B7307FC2-4FCD-44D5-A009-54447911EC0C',
#   'DataProviderID': 2,
#   'DataProvidersReference': '322167',
#   'OperatorID': 5,
#   'UsageTypeID': 1,
#   'AddressInfo': {'ID': 294817,
#    'Title': 'LAZ COLUMBUS OH MARCONI BLVD',
#    'AddressLine1': '245 Marconi Blvd',
#    'Town': 'Columbus',
#    'StateOrProvince': 'OH',
#    'Postcode': '43215',
#    'CountryID': 2,
#    'Latitude': 39.967285,
#    'Longitude': -83.006446,
#    'ContactTelephone1': '888-758-4389',
#    'AccessComments': '24 hours daily',
#    'RelatedURL': 'http://www.chargepoint.com/',
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 525786,
#     'ConnectionTypeID': 1,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 3.7,
#     'CurrentTypeID': 10,
#     'Quantity': 2,
#     'Comments': 'kW power is an estimate based on the connection type'}],
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-02-20T10:15:00Z',
#   'DataQualityLevel': 3,
#   'DateCreated': '2024-02-20T10:15:00Z',
#   'SubmissionStatusTypeID': 100},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2024-02-20T10:15:00Z',
#   'ID': 294429,
#   'UUID': '67537216-6005-4B6D-A62F-81674A5C095D',
#   'DataProviderID': 2,
#   'DataProvidersReference': '323803',
#   'OperatorID': 5,
#   'UsageTypeID': 1,
#   'AddressInfo': {'ID': 294816,
#    'Title': 'PHILLY VM PHILLY VM BASE',
#    'AddressLine1': '1043-69 N Front St',
#    'Town': 'Philadelphia',
#    'StateOrProvince': 'PA',
#    'Postcode': '19123',
#    'CountryID': 2,
#    'Latitude': 39.966927,
#    'Longitude': -75.13654,
#    'ContactTelephone1': '888-758-4389',
#    'AccessComments': '24 hours daily',
#    'RelatedURL': 'http://www.chargepoint.com/',
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 525785,
#     'ConnectionTypeID': 1,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 3.7,
#     'CurrentTypeID': 10,
#     'Quantity': 1,
#     'Comments': 'kW power is an estimate based on the connection type'}],
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-02-20T10:15:00Z',
#   'DataQualityLevel': 3,
#   'DateCreated': '2024-02-20T10:15:00Z',
#   'SubmissionStatusTypeID': 100},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2024-03-26T12:44:00Z',
#   'ID': 294428,
#   'UUID': 'F758E9CA-676B-4811-8D41-3BE681469614',
#   'DataProviderID': 1,
#   'OperatorID': 15,
#   'UsageTypeID': 1,
#   'AddressInfo': {'ID': 294815,
#    'Title': 'Pilot Travel Center',
#    'AddressLine1': '1365 US-42',
#    'Town': 'London',
#    'StateOrProvince': 'OH',
#    'Postcode': '43140',
#    'CountryID': 2,
#    'Latitude': 39.9593845,
#    'Longitude': -83.3689943,
#    'ContactTelephone1': '877-455-3833',
#    'AccessComments': '24 hours daily',
#    'RelatedURL': 'https://www.evgo.com/',
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 525784,
#     'ConnectionTypeID': 32,
#     'LevelID': 3,
#     'PowerKW': 350,
#     'CurrentTypeID': 30,
#     'Quantity': 4,
#     'Comments': ''}],
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2024-03-26T12:44:00Z',
#   'DataQualityLevel': 3,
#   'DateCreated': '2024-02-20T10:15:00Z',
#   'SubmissionStatusTypeID': 100}]

# %%
extracted_data = []

for entry in charging_data:
    if 'AddressInfo' in entry:
        latitude = entry['AddressInfo'].get('Latitude', None)
        longitude = entry['AddressInfo'].get('Longitude', None)
        title = entry['AddressInfo'].get('Title', None)
        for connection in entry.get('Connections', []):
            extracted_data.append({
                'Latitude': latitude,
                'Longitude': longitude,
                'Title': title,
                # Add other fields from the connection if needed
            })

charging_df1 = pd.DataFrame(extracted_data)
print(charging_df1.head())
# Out:
#     Latitude   Longitude                        Title
# 0  35.189918 -106.636386                 Melloy Dodge
# 1  35.189918 -106.636386                 Melloy Dodge
# 2  35.189918 -106.636386                 Melloy Dodge
# 3  35.189918 -106.636386                 Melloy Dodge
# 4  43.038698 -108.379586  Fremont Chevrolet Buick GMC

# %%
len(charging_df1)
# Out:
# 1246

# %%
# Flatten the JSON data with the available fields
charging_df2 = json_normalize(charging_data,
                             record_path=['Connections'],
                             meta=['AddressInfo.Latitude',
                                   'AddressInfo.Longitude',
                                   'AddressInfo.Title'],
                             errors='ignore')

# Select the available columns
charging_df2 = charging_df2[['AddressInfo.Latitude', 'AddressInfo.Longitude', 'AddressInfo.Title',
                           'ConnectionTypeID', 'Amps', 'Voltage', 'PowerKW', 'Quantity', 'Comments']]

# Display the first few rows to verify the selection
print(charging_df2.head())
# Out:
#   AddressInfo.Latitude AddressInfo.Longitude AddressInfo.Title  \
# 0                  NaN                   NaN               NaN
# 1                  NaN                   NaN               NaN
# 2                  NaN                   NaN               NaN
# 3                  NaN                   NaN               NaN
# 4                  NaN                   NaN               NaN
#
#    ConnectionTypeID   Amps  Voltage  PowerKW  Quantity            Comments
# 0                 1   80.0    208.0     19.2         2       Near Building
# 1                32  200.0    480.0    125.0         2  Under solar canopy
# 2                 2  200.0    480.0    125.0         2  Under solar canopy
# 3                32  400.0    480.0    180.0         2  Under solar canopy
# 4                32    NaN      NaN     60.0         2                 NaN

# %%
charging_df2 = charging_df2.drop(charging_df2.columns[:3], axis=1)

# %%
print(charging_df2.head())
# Out:
#    ConnectionTypeID   Amps  Voltage  PowerKW  Quantity            Comments
# 0                 1   80.0    208.0     19.2         2       Near Building
# 1                32  200.0    480.0    125.0         2  Under solar canopy
# 2                 2  200.0    480.0    125.0         2  Under solar canopy
# 3                32  400.0    480.0    180.0         2  Under solar canopy
# 4                32    NaN      NaN     60.0         2                 NaN

# %%
len(charging_df2)
# Out:
# 1246

# %%
charging_df = pd.concat([charging_df1, charging_df2], axis=1)

# %%
charging_df.shape
# Out:
# (1246, 9)

# %%
charging_df.columns = ['Latitude', 'Longitude', 'Station_Name', 'ConnectionTypeID', 'Amps', 'Voltage', 'PowerKW', 'Quantity', 'Comments']

# Display the first few rows to verify
print(charging_df.head())
# Out:
#     Latitude   Longitude                 Station_Name  ConnectionTypeID  \
# 0  35.189918 -106.636386                 Melloy Dodge                 1
# 1  35.189918 -106.636386                 Melloy Dodge                32
# 2  35.189918 -106.636386                 Melloy Dodge                 2
# 3  35.189918 -106.636386                 Melloy Dodge                32
# 4  43.038698 -108.379586  Fremont Chevrolet Buick GMC                32
#
#     Amps  Voltage  PowerKW  Quantity            Comments
# 0   80.0    208.0     19.2         2       Near Building
# 1  200.0    480.0    125.0         2  Under solar canopy
# 2  200.0    480.0    125.0         2  Under solar canopy
# 3  400.0    480.0    180.0         2  Under solar canopy
# 4    NaN      NaN     60.0         2                 NaN

# %% [markdown]
# b. Download and Prepare Road Network Data

# %%
# Define the area of interest
place = "San Francisco, California, USA"

# Download the street network
G = ox.graph_from_place(place, network_type='drive')

# Attempt to simplify the graph and handle the error
try:
    G = ox.simplify_graph(G)
except:
    print("Graph has already been simplified. Skipping simplification.")
    G.simplified = True

# Get node and edge data
nodes, edges = ox.graph_to_gdfs(G)
# Out:
# Graph has already been simplified. Skipping simplification.

# %% [markdown]
# c. Obtain Traffic Data
#
# Note: Traffic data integration depends on the chosen API. Here's a conceptual example.

# %%
# API ID: beGP5pHvdK7Xip6dNpjI
# API KEY: uGmZJmrJp8qyasBBu9QA_P9pJJqMwchevPw8wUiHRas

# %%
# Example using HERE Traffic API
TRAFFIC_API_KEY = 'API' # Replace with your API key
traffic_url = 'https://traffic.ls.hereapi.com/traffic/6.3/flow.json'

params = {
    'apiKey': TRAFFIC_API_KEY,
    'bbox': '37.7749,-122.4194;37.8044,-122.2712',  # Define bounding box
}

response = requests.get(traffic_url, params=params)
traffic_data = response.json()

# %%
traffic_data
# Out:
# {'title': 'Forbidden.',
#  'status': 403,
#  'code': '403403',
#  'cause': 'App beGP5pHvdK7Xip6dNpjI credentials do not authorize access to perform GET action on hrn:here:tdaflowinc::HERE:traffic_63_flow via SERVICE-3839cf60-7483-43a1-98c9-3d150a4d9af0 because no matching permissions found for the identity, its groups and roles, or the realm.',
#  'action': 'Add/Share the necessary permissions to the identity.',
#  'correlationId': '36260000-f51e-464f-9dd3-d654536f5b9d',
#  'error': 'Forbidden',
#  'details': [],
#  'error_description': 'These credentials do not authorize access'}

# %% [markdown]
# ## Routing Optimization
#
# a. Define Origin and Destination

# %%
geolocator = Nominatim(user_agent="ev_routing")
origin = geolocator.geocode("Golden Gate Bridge, San Francisco, CA")
destination = geolocator.geocode("Fisherman's Wharf, San Francisco, CA")

origin_point = (origin.latitude, origin.longitude)
destination_point = (destination.latitude, destination.longitude)

# %%
destination_point
# Out:
# (37.8081325, -122.4165913)

# %% [markdown]
# b. Find Nearest Nodes in the Graph

# %%
origin_node = ox.distance.nearest_nodes(G, origin.longitude, origin.latitude)
destination_node = ox.distance.nearest_nodes(G, destination.longitude, destination.latitude)

# %%
destination_node
# Out:
# 65344021

# %% [markdown]
# c. Calculate Optimal Route Considering Traffic

# %%
# Modify edge weights based on traffic data
# This step requires processing traffic_data to adjust 'travel_time' or 'speed'

# Example: If traffic is heavy, increase travel time on affected edges
for edge in G.edges(data=True):
    if 'traffic_condition' in edge[2]:
        if edge[2]['traffic_condition'] == 'heavy':
            G[edge[0]][edge[1]][edge[2]['key']]['travel_time'] *= 1.5  # Increase travel time by 50%

# Compute the shortest path based on travel_time
route = nx.shortest_path(G, origin_node, destination_node, weight='travel_time')

# %% [markdown]
# ## Charging Optimization
#
# a. Determine EV's Range and Charging Needs

# %%
# EV Specifications
battery_capacity_kWh = 75  # Example: 75 kWh
current_charge_kWh = 50
energy_consumption_kWh_per_mile = 0.3  # Example consumption rate

# Calculate remaining range
remaining_range = current_charge_kWh / energy_consumption_kWh_per_mile  # in miles

# %%
remaining_range
# Out:
# 166.66666666666669

# %% [markdown]
# b. Identify Charging Stations Along the Route

# %%
# Convert route nodes to geographic coordinates
route_coords = [(G.nodes[node]['y'], G.nodes[node]['x']) for node in route]

# Function to find charging stations within a certain distance from the route
from shapely.geometry import Point, LineString

route_line = LineString([(x[1], x[0]) for x in route_coords])  # Note: shapely uses (x, y)

def find_nearby_stations(charging_df, route_line, buffer=0.09):
    """Find charging stations within buffer degrees of the route."""
    nearby = charging_df[
        charging_df.apply(
            lambda row: route_line.distance(Point(row['Longitude'], row['Latitude'])) > 0, axis=1
        )
    ]
    return nearby

nearby_stations = find_nearby_stations(charging_df, route_line)

# %%
nearby_stations
# Out:
#        Latitude   Longitude                    Station_Name  ConnectionTypeID  \
# 0     35.189918 -106.636386                    Melloy Dodge                 1
# 1     35.189918 -106.636386                    Melloy Dodge                32
# 2     35.189918 -106.636386                    Melloy Dodge                 2
# 3     35.189918 -106.636386                    Melloy Dodge                32
# 4     43.038698 -108.379586     Fremont Chevrolet Buick GMC                32
# ...         ...         ...                             ...               ...
# 1241  39.985070 -105.229440                Iconergy Boulder                 1
# 1242  39.972543  -76.671386  AAA MID STATES AAA MID STATES1                 1
# 1243  39.967285  -83.006446    LAZ COLUMBUS OH MARCONI BLVD                 1
# 1244  39.966927  -75.136540        PHILLY VM PHILLY VM BASE                 1
# 1245  39.959384  -83.368994             Pilot Travel Center                32
#
#        Amps  Voltage  PowerKW  Quantity  \
# 0      80.0    208.0     19.2         2
# 1     200.0    480.0    125.0         2
# 2     200.0    480.0    125.0         2
# 3     400.0    480.0    180.0         2
# 4       NaN      NaN     60.0         2
# ...     ...      ...      ...       ...
# 1241   16.0    230.0      3.7         4
# 1242   16.0    230.0      3.7         2
# 1243   16.0    230.0      3.7         2
# 1244   16.0    230.0      3.7         1
# 1245    NaN      NaN    350.0         4
#
#                                                Comments
# 0                                         Near Building
# 1                                    Under solar canopy
# 2                                    Under solar canopy
# 3                                    Under solar canopy
# 4                                                   NaN
# ...                                                 ...
# 1241  kW power is an estimate based on the connectio...
# 1242  kW power is an estimate based on the connectio...
# 1243  kW power is an estimate based on the connectio...
# 1244  kW power is an estimate based on the connectio...
# 1245
#
# [1246 rows x 9 columns]

# %% [markdown]
# c. Optimize Charging Stops

# %%
# Define the optimization problem
prob = LpProblem("EV_Charging_Optimization", LpMinimize)

# Variables: Whether to stop at a charging station or not
charging_stops = LpVariable.dicts("Stop", nearby_stations.index, 0, 1, LpBinary)

# Objective: Minimize total charging time or cost
# For simplicity, minimize the number of stops
prob += lpSum([charging_stops[i] for i in nearby_stations.index])

# Constraints:
# Ensure that the EV does not run out of battery between charging stops
# This requires calculating distances between charging stations and ensuring they are within the EV's range

# Example constraint (simplified):
# Assuming stations are ordered along the route
max_range_miles = remaining_range
for i in range(len(nearby_stations) - 1):
    distance = ...  # Calculate distance between station i and i+1
    prob += charging_stops[i] + charging_stops[i+1] >= 1  # At least one stop within range

# Solve the problem
prob.solve()

# Extract selected charging stops
# selected_stops = nearby_stations[charging_stops[i].varValue == 1 for i in nearby_stations.index]
selected_stops = [station for i, station in nearby_stations.iterrows() if charging_stops[i].varValue == 1]

# %%
selected_stops
# Out:
# [Latitude                     35.189918
#  Longitude                  -106.636386
#  Station_Name              Melloy Dodge
#  ConnectionTypeID                    32
#  Amps                             200.0
#  Voltage                          480.0
#  PowerKW                          125.0
#  Quantity                             2
#  Comments            Under solar canopy
#  Name: 1, dtype: object,
#  Latitude                     35.189918
#  Longitude                  -106.636386
#  Station_Name              Melloy Dodge
#  ConnectionTypeID                    32
#  Amps                             400.0
#  Voltage                          480.0
#  PowerKW                          180.0
#  Quantity                             2
#  Comments            Under solar canopy
#  Name: 3, dtype: object,
#  Latitude                          38.886198
#  Longitude                        -77.431604
#  Station_Name        G&C EV Charging Station
#  ConnectionTypeID                         27
#  Amps                                   28.0
#  Voltage                               240.0
#  PowerKW                                 6.7
#  Quantity                                  1
#  Comments                                NaN
#  Name: 5, dtype: object,
#  Latitude                                                    38.892351
#  Longitude                                                  -77.421361
#  Station_Name                                G&C EV Juice Bar Manassas
#  ConnectionTypeID                                                    1
#  Amps                                                             28.0
#  Voltage                                                         240.0
#  PowerKW                                                          40.5
#  Quantity                                                            1
#  Comments            Please give us feedback on improvements we can...
#  Name: 7, dtype: object,
#  Latitude                                                    38.878002
#  Longitude                                                  -77.443222
#  Station_Name                                         G&C EV Juice Bar
#  ConnectionTypeID                                                   27
#  Amps                                                             30.0
#  Voltage                                                         240.0
#  PowerKW                                                          40.0
#  Quantity                                                            2
#  Comments            One is located on each corner of the building.
#  Name: 9, dtype: object,
#  Latitude               34.159434
#  Longitude            -118.096186
#  Station_Name        Victory Park
#  ConnectionTypeID               1
#  Amps                         NaN
#  Voltage                      NaN
#  PowerKW                      NaN
#  Quantity                      19
#  Comments                     NaN
#  Name: 11, dtype: object,
#  Latitude               34.159434
#  Longitude            -118.096186
#  Station_Name        Victory Park
#  ConnectionTypeID               2
#  Amps                         NaN
#  Voltage                      NaN
#  PowerKW                     50.0
#  Quantity                       3
#  Comments                     NaN
#  Name: 13, dtype: object,
#  Latitude                                38.426995
#  Longitude                             -122.741831
#  Station_Name        ChargeNet TacoBell Santa Rosa
#  ConnectionTypeID                                2
#  Amps                                          NaN
#  Voltage                                       NaN
#  PowerKW                                      75.0
#  Quantity                                        5
#  Comments                                      NaN
#  Name: 15, dtype: object,
#  Latitude                                  38.364613
#  Longitude                                -122.71344
#  Station_Name        ChargeNet TacoBell Rohnert Park
#  ConnectionTypeID                                  2
#  Amps                                            NaN
#  Voltage                                         NaN
#  PowerKW                                        75.0
#  Quantity                                          4
#  Comments                                        NaN
#  Name: 17, dtype: object,
#  Latitude                  38.63926
#  Longitude              -121.521933
#  Station_Name        Cosrco Natomas
#  ConnectionTypeID                32
#  Amps                           NaN
#  Voltage                     1000.0
#  PowerKW                      350.0
#  Quantity                        10
#  Comments                       NaN
#  Name: 19, dtype: object,
#  Latitude                   39.641293
#  Longitude                -105.027365
#  Station_Name        City of Sheridan
#  ConnectionTypeID                  32
#  Amps                             NaN
#  Voltage                          NaN
#  PowerKW                        120.0
#  Quantity                           2
#  Comments                         NaN
#  Name: 21, dtype: object,
#  Latitude                       42.380878
#  Longitude                    -122.927292
#  Station_Name        Boulder Ridge Street
#  ConnectionTypeID                       1
#  Amps                                 NaN
#  Voltage                              NaN
#  PowerKW                              4.0
#  Quantity                               2
#  Comments                             NaN
#  Name: 23, dtype: object,
#  Latitude                 35.164262
#  Longitude               -83.392828
#  Station_Name        Franklin Plaza
#  ConnectionTypeID                27
#  Amps                           NaN
#  Voltage                        NaN
#  PowerKW                      250.0
#  Quantity                        12
#  Comments                       NaN
#  Name: 25, dtype: object,
#  Latitude            40.486815
#  Longitude          -89.045191
#  Station_Name         Circle K
#  ConnectionTypeID           32
#  Amps                      NaN
#  Voltage                   NaN
#  PowerKW                 180.0
#  Quantity                    3
#  Comments                  NaN
#  Name: 27, dtype: object,
#  Latitude            43.874943
#  Longitude          -91.195871
#  Station_Name        Dahl Ford
#  ConnectionTypeID           32
#  Amps                      NaN
#  Voltage                   NaN
#  PowerKW                 240.0
#  Quantity                    1
#  Comments                  NaN
#  Name: 29, dtype: object,
#  Latitude                         42.399878
#  Longitude                      -122.907011
#  Station_Name        Rusted Gate Farm store
#  ConnectionTypeID                         1
#  Amps                                   NaN
#  Voltage                                NaN
#  PowerKW                                8.0
#  Quantity                                 2
#  Comments                               NaN
#  Name: 31, dtype: object,
#  Latitude                                             39.925465
#  Longitude                                           -83.810416
#  Station_Name        Public Parking Garage - Greenspot charging
#  ConnectionTypeID                                             1
#  Amps                                                       NaN
#  Voltage                                                    NaN
#  PowerKW                                                    NaN
#  Quantity                                                     2
#  Comments                               Greenspot APP required
#  Name: 33, dtype: object,
#  Latitude                                                    42.330696
#  Longitude                                                  -71.254761
#  Station_Name        ChargePoint - Newton Service Plaza I-95 Southb...
#  ConnectionTypeID                                                   32
#  Amps                                                              NaN
#  Voltage                                                           NaN
#  PowerKW                                                          62.5
#  Quantity                                                            2
#  Comments                                                          NaN
#  Name: 35, dtype: object,
#  Latitude                                         42.311934
#  Longitude                                       -71.429016
#  Station_Name        Autel - Framingham Rest Stop Westbound
#  ConnectionTypeID                                        32
#  Amps                                                   NaN
#  Voltage                                                NaN
#  PowerKW                                               60.0
#  Quantity                                                 2
#  Comments                                               NaN
#  Name: 37, dtype: object,
#  Latitude                    34.062257
#  Longitude                  -83.273647
#  Station_Name        Jackson EMC Neese
#  ConnectionTypeID                   32
#  Amps                              NaN
#  Voltage                           NaN
#  PowerKW                           NaN
#  Quantity                            1
#  Comments                          NaN
#  Name: 39, dtype: object,
#  Latitude                 38.350474
#  Longitude                -81.63817
#  Station_Name        Laidley Garage
#  ConnectionTypeID                 1
#  Amps                           NaN
#  Voltage                        NaN
#  PowerKW                        7.8
#  Quantity                         2
#  Comments                       NaN
#  Name: 41, dtype: object,
#  Latitude                  34.735265
#  Longitude                -87.668021
#  Station_Name        Long-Lewis Ford
#  ConnectionTypeID                 33
#  Amps                            NaN
#  Voltage                         NaN
#  PowerKW                         NaN
#  Quantity                          2
#  Comments                        NaN
#  Name: 43, dtype: object,
#  Latitude                                   61.191507
#  Longitude                                 -149.87009
#  Station_Name        ReCharge Alaska Charging Station
#  ConnectionTypeID                                  32
#  Amps                                           200.0
#  Voltage                                        920.0
#  PowerKW                                         75.0
#  Quantity                                           2
#  Comments                                         NaN
#  Name: 45, dtype: object,
#  Latitude                           41.801169
#  Longitude                         -72.542489
#  Station_Name        The Vintage at the Grove
#  ConnectionTypeID                           1
#  Amps                                    50.0
#  Voltage                                230.0
#  PowerKW                                 11.5
#  Quantity                                   2
#  Comments                                 NaN
#  Name: 47, dtype: object,
#  Latitude                           41.801169
#  Longitude                         -72.542489
#  Station_Name        The Vintage at the Grove
#  ConnectionTypeID                           1
#  Amps                                    50.0
#  Voltage                                230.0
#  PowerKW                                 11.5
#  Quantity                                   2
#  Comments                                 NaN
#  Name: 49, dtype: object,
#  Latitude                                                    40.269431
#  Longitude                                                  -76.677277
#  Station_Name                                           Hershey Lodge
#  ConnectionTypeID                                                    1
#  Amps                                                              NaN
#  Voltage                                                           NaN
#  PowerKW                                                           6.0
#  Quantity                                                            2
#  Comments            charge lab shows this charger has 11kw, but ac...
#  Name: 51, dtype: object,
#  Latitude             44.950605
#  Longitude          -122.998218
#  Station_Name              ARCO
#  ConnectionTypeID            32
#  Amps                       NaN
#  Voltage                    NaN
#  PowerKW                  150.0
#  Quantity                     5
#  Comments                   NaN
#  Name: 53, dtype: object,
#  Latitude                                42.206913
#  Longitude                             -121.735788
#  Station_Name        Grocery Outlet - Supercharger
#  ConnectionTypeID                               27
#  Amps                                          NaN
#  Voltage                                       NaN
#  PowerKW                                     250.0
#  Quantity                                        8
#  Comments                                      NaN
#  Name: 55, dtype: object,
#  Latitude                                                    38.403634
#  Longitude                                                 -122.697243
#  Station_Name                            Taylor Mountain Regional Park
#  ConnectionTypeID                                                    1
#  Amps                                                             20.0
#  Voltage                                                         240.0
#  PowerKW                                                           5.0
#  Quantity                                                            2
#  Comments            Portable solar powered EV charging station. Fr...
#  Name: 57, dtype: object,
#  Latitude                          32.645765
#  Longitude                       -116.968199
#  Station_Name        Eastlake Village Center
#  ConnectionTypeID                          2
#  Amps                                    NaN
#  Voltage                                 NaN
#  PowerKW                               100.0
#  Quantity                                  1
#  Comments                                NaN
#  Name: 59, dtype: object,
#  Latitude             39.291919
#  Longitude          -120.678457
#  Station_Name        Nyack Road
#  ConnectionTypeID            32
#  Amps                       NaN
#  Voltage                    NaN
#  PowerKW                   50.0
#  Quantity                     2
#  Comments                   NaN
#  Name: 61, dtype: object,
#  Latitude                                            45.5683
#  Longitude                                       -122.599673
#  Station_Name        Plaid Pantry PowerNode Charging Station
#  ConnectionTypeID                                          2
#  Amps                                                  200.0
#  Voltage                                               500.0
#  PowerKW                                               100.0
#  Quantity                                                  1
#  Comments                                                NaN
#  Name: 63, dtype: object,
#  Latitude             38.676947
#  Longitude          -121.743811
#  Station_Name          7-Eleven
#  ConnectionTypeID            32
#  Amps                       NaN
#  Voltage                    NaN
#  PowerKW                  180.0
#  Quantity                     3
#  Comments                   NaN
#  Name: 65, dtype: object,
#  Latitude             34.972608
#  Longitude          -120.435453
#  Station_Name          7-Eleven
#  ConnectionTypeID            32
#  Amps                       NaN
#  Voltage                    NaN
#  PowerKW                  180.0
#  Quantity                     3
#  Comments                   NaN
#  Name: 67, dtype: object,
#  Latitude             38.591119
#  Longitude          -121.547824
#  Station_Name              ARCO
#  ConnectionTypeID             2
#  Amps                       NaN
#  Voltage                    NaN
#  PowerKW                  100.0
#  Quantity                     1
#  Comments                   NaN
#  Name: 69, dtype: object,
#  Latitude             37.989438
#  Longitude          -121.321708
#  Station_Name             AM/PM
#  ConnectionTypeID            32
#  Amps                       NaN
#  Voltage                    NaN
#  PowerKW                  150.0
#  Quantity                     4
#  Comments                   NaN
#  Name: 71, dtype: object,
#  Latitude                       37.460065
#  Longitude                    -122.138786
#  Station_Name        Ikea - Superchargers
#  ConnectionTypeID                      27
#  Amps                                 NaN
#  Voltage                              NaN
#  PowerKW                            250.0
#  Quantity                              20
#  Comments                             NaN
#  Name: 73, dtype: object,
#  Latitude                          36.844365
#  Longitude                       -119.786926
#  Station_Name        PetSmart - Supercharger
#  ConnectionTypeID                         27
#  Amps                                    NaN
#  Voltage                                 NaN
#  PowerKW                               250.0
#  Quantity                                 12
#  Comments                                NaN
#  Name: 75, dtype: object,
#  Latitude                    33.95435
#  Longitude                 -118.11469
#  Station_Name        Downy Crossroads
#  ConnectionTypeID                  32
#  Amps                             NaN
#  Voltage                          NaN
#  PowerKW                        350.0
#  Quantity                           8
#  Comments                         NaN
#  Name: 77, dtype: object,
#  Latitude             34.073753
#  Longitude          -117.370579
#  Station_Name            Panera
#  ConnectionTypeID            32
#  Amps                       NaN
#  Voltage                    NaN
#  PowerKW                  100.0
#  Quantity                     4
#  Comments                   NaN
#  Name: 79, dtype: object,
#  Latitude                    38.631661
#  Longitude                 -121.476887
#  Station_Name        Foodsco Northgate
#  ConnectionTypeID                   32
#  Amps                              NaN
#  Voltage                           NaN
#  PowerKW                         350.0
#  Quantity                            2
#  Comments                          NaN
#  Name: 81, dtype: object,
#  Latitude                    38.631661
#  Longitude                 -121.476887
#  Station_Name        Foodsco Northgate
#  ConnectionTypeID                    2
#  Amps                              NaN
#  Voltage                           NaN
#  PowerKW                         100.0
#  Quantity                            4
#  Comments                          NaN
#  Name: 83, dtype: object,
#  Latitude               37.97317
#  Longitude            -122.04196
#  Station_Name        Park & Shop
#  ConnectionTypeID             32
#  Amps                        NaN
#  Voltage                     NaN
#  PowerKW                   350.0
#  Quantity                     10
#  Comments                    NaN
#  Name: 85, dtype: object,
#  Latitude              37.962757
#  Longitude           -121.994209
#  Station_Name        Treat Plaza
#  ConnectionTypeID             32
#  Amps                        NaN
#  Voltage                     NaN
#  PowerKW                   350.0
#  Quantity                      6
#  Comments                    NaN
#  Name: 87, dtype: object,
#  Latitude                              37.278824
#  Longitude                           -121.835358
#  Station_Name        Seven Trees Shopping Center
#  ConnectionTypeID                              2
#  Amps                                        NaN
#  Voltage                                     NaN
#  PowerKW                                   100.0
#  Quantity                                      6
#  Comments                                    NaN
#  Name: 89, dtype: object,
#  Latitude                              37.278824
#  Longitude                           -121.835358
#  Station_Name        Seven Trees Shopping Center
#  ConnectionTypeID                             32
#  Amps                                        NaN
#  Voltage                                     NaN
#  PowerKW                                   100.0
#  Quantity                                      2
#  Comments                                    NaN
#  Name: 91, dtype: object,
#  Latitude                             37.656204
#  Longitude                          -122.411246
#  Station_Name        Miller Garage HPCP Array 1
#  ConnectionTypeID                            32
#  Amps                                       NaN
#  Voltage                                    NaN
#  PowerKW                                   50.0
#  Quantity                                     3
#  Comments                                   NaN
#  Name: 93, dtype: object,
#  Latitude                37.260359
#  Longitude             -121.876013
#  Station_Name        Almaden Plaza
#  ConnectionTypeID               32
#  Amps                          NaN
#  Voltage                       NaN
#  PowerKW                     100.0
#  Quantity                        4
#  Comments                      NaN
#  Name: 95, dtype: object,
#  Latitude                      41.421657
#  Longitude                   -122.384839
#  Station_Name        Weed - Supercharger
#  ConnectionTypeID                     27
#  Amps                                NaN
#  Voltage                             NaN
#  PowerKW                           250.0
#  Quantity                             16
#  Comments                            NaN
#  Name: 97, dtype: object,
#  Latitude                                                     44.98791
#  Longitude                                                   -93.22865
#  Station_Name                                        Nelson Auto World
#  ConnectionTypeID                                                   32
#  Amps                                                              NaN
#  Voltage                                                           NaN
#  PowerKW                                                          50.0
#  Quantity                                                            2
#  Comments            kW power is an estimate based on the connectio...
#  Name: 99, dtype: object,
#  Latitude                    44.730421
#  Longitude                  -93.210751
#  Station_Name        Apple Valley Ford
#  ConnectionTypeID                   32
#  Amps                              NaN
#  Voltage                           NaN
#  PowerKW                          24.0
#  Quantity                            5
#  Comments                          NaN
#  Name: 101, dtype: object,
#  Latitude             45.01404
#  Longitude          -93.460665
#  Station_Name         Circke K
#  ConnectionTypeID           32
#  Amps                      NaN
#  Voltage                   NaN
#  PowerKW                 180.0
#  Quantity                    4
#  Comments                  NaN
#  Name: 103, dtype: object,
#  Latitude              47.740087
#  Longitude           -117.409868
#  Station_Name        Wendle Fort
#  ConnectionTypeID              1
#  Amps                        NaN
#  Voltage                     NaN
#  PowerKW                    19.2
#  Quantity                      1
#  Comments                    NaN
#  Name: 105, dtype: object,
#  Latitude             44.084738
#  Longitude          -123.041027
#  Station_Name              AMPM
#  ConnectionTypeID             2
#  Amps                       NaN
#  Voltage                    NaN
#  PowerKW                   41.0
#  Quantity                     2
#  Comments                   NaN
#  Name: 107, dtype: object,
#  Latitude                                    35.703586
#  Longitude                                   -83.51309
#  Station_Name        Hampton Inn Historic Nature Trail
#  ConnectionTypeID                                    1
#  Amps                                              NaN
#  Voltage                                           NaN
#  PowerKW                                          10.0
#  Quantity                                            3
#  Comments                                          NaN
#  Name: 109, dtype: object,
#  Latitude                                            42.940123
#  Longitude                                         -123.290776
#  Station_Name        Seven Feathers PowerNode Charging Station
#  ConnectionTypeID                                           32
#  Amps                                                    350.0
#  Voltage                                                1000.0
#  PowerKW                                                 200.0
#  Quantity                                                    1
#  Comments                                                  NaN
#  Name: 111, dtype: object,
#  Latitude                                            42.940123
#  Longitude                                         -123.290776
#  Station_Name        Seven Feathers PowerNode Charging Station
#  ConnectionTypeID                                           32
#  Amps                                                    350.0
#  Voltage                                                1000.0
#  PowerKW                                                 200.0
#  Quantity                                                    1
#  Comments                                                  NaN
#  Name: 113, dtype: object,
#  Latitude                                            42.940123
#  Longitude                                         -123.290776
#  Station_Name        Seven Feathers PowerNode Charging Station
#  ConnectionTypeID                                           32
#  Amps                                                    350.0
#  Voltage                                                1000.0
#  PowerKW                                                 200.0
#  Quantity                                                    1
#  Comments                                                  NaN
#  Name: 115, dtype: object,
#  Latitude                                            42.940123
#  Longitude                                         -123.290776
#  Station_Name        Seven Feathers PowerNode Charging Station
#  ConnectionTypeID                                           32
#  Amps                                                    350.0
#  Voltage                                                1000.0
#  PowerKW                                                 200.0
#  Quantity                                                    1
#  Comments                                                  NaN
#  Name: 117, dtype: object,
#  Latitude                                            42.940123
#  Longitude                                         -123.290776
#  Station_Name        Seven Feathers PowerNode Charging Station
#  ConnectionTypeID                                           32
#  Amps                                                    350.0
#  Voltage                                                1000.0
#  PowerKW                                                 200.0
#  Quantity                                                    1
#  Comments                                                  NaN
#  Name: 119, dtype: object,
#  Latitude                                            42.940123
#  Longitude                                         -123.290776
#  Station_Name        Seven Feathers PowerNode Charging Station
#  ConnectionTypeID                                           32
#  Amps                                                    350.0
#  Voltage                                                1000.0
#  PowerKW                                                 200.0
#  Quantity                                                    1
#  Comments                                                  NaN
#  Name: 121, dtype: object,
#  Latitude                                         42.200808
#  Longitude                                       -70.942073
#  Station_Name        Quik Charge PowerNode Charging Station
#  ConnectionTypeID                                        32
#  Amps                                                 350.0
#  Voltage                                             1000.0
#  PowerKW                                              200.0
#  Quantity                                                 1
#  Comments                                               NaN
#  Name: 123, dtype: object,
#  Latitude                              43.70405
#  Longitude                           -71.111562
#  Station_Name        KOGO (Kilowatts On the GO)
#  ConnectionTypeID                             1
#  Amps                                      80.0
#  Voltage                                  240.0
#  PowerKW                                   19.2
#  Quantity                                     2
#  Comments                                   NaN
#  Name: 125, dtype: object,
#  Latitude             46.271318
#  Longitude          -119.220767
#  Station_Name          Circle K
#  ConnectionTypeID            32
#  Amps                       NaN
#  Voltage                    NaN
#  PowerKW                  180.0
#  Quantity                     4
#  Comments                   NaN
#  Name: 127, dtype: object,
#  Latitude             47.545799
#  Longitude          -122.059602
#  Station_Name         Starbucks
#  ConnectionTypeID            32
#  Amps                       NaN
#  Voltage                    NaN
#  PowerKW                   62.5
#  Quantity                     4
#  Comments                   NaN
#  Name: 129, dtype: object,
#  Latitude             48.241439
#  Longitude          -122.374548
#  Station_Name              Arco
#  ConnectionTypeID             2
#  Amps                       NaN
#  Voltage                    NaN
#  PowerKW                  100.0
#  Quantity                     1
#  Comments                   NaN
#  Name: 131, dtype: object,
#  Latitude              46.96949
#  Longitude          -123.824042
#  Station_Name              Arco
#  ConnectionTypeID             2
#  Amps                       NaN
#  Voltage                    NaN
#  PowerKW                  100.0
#  Quantity                     1
#  Comments                   NaN
#  Name: 133, dtype: object,
#  Latitude                                    47.814041
#  Longitude                                 -122.206422
#  Station_Name        Sound Credit Union - Supercharger
#  ConnectionTypeID                                   27
#  Amps                                              NaN
#  Voltage                                           NaN
#  PowerKW                                         250.0
#  Quantity                                           12
#  Comments                                          NaN
#  Name: 135, dtype: object,
#  Latitude                                    47.189564
#  Longitude                                 -122.460313
#  Station_Name        Elmer's Restaurant - Supercharger
#  ConnectionTypeID                                   27
#  Amps                                              NaN
#  Voltage                                           NaN
#  PowerKW                                         250.0
#  Quantity                                           12
#  Comments                                          NaN
#  Name: 137, dtype: object,
#  Latitude                    46.426153
#  Longitude                 -117.047829
#  Station_Name        Granite Park DCFC
#  ConnectionTypeID                   32
#  Amps                              NaN
#  Voltage                           NaN
#  PowerKW                         180.0
#  Quantity                            4
#  Comments                          NaN
#  Name: 139, dtype: object,
#  Latitude                       37.994159
#  Longitude                     -79.834682
#  Station_Name        Vine Cottage Inn B&B
#  ConnectionTypeID                       1
#  Amps                                48.0
#  Voltage                            240.0
#  PowerKW                             11.4
#  Quantity                               1
#  Comments                     Guests only
#  Name: 141, dtype: object,
#  Latitude                      34.345586
#  Longitude                    -119.08052
#  Station_Name         Santa Paula Center
#  ConnectionTypeID                     32
#  Amps                                NaN
#  Voltage                             NaN
#  PowerKW                           350.0
#  Quantity                              4
#  Comments                            NaN
#  Name: 143, dtype: object,
#  Latitude             33.746966
#  Longitude          -117.865397
#  Station_Name         Food4Less
#  ConnectionTypeID            32
#  Amps                       NaN
#  Voltage                    NaN
#  PowerKW                  350.0
#  Quantity                     2
#  Comments                   NaN
#  Name: 145, dtype: object,
#  Latitude                     33.20125
#  Longitude                  -117.33248
#  Station_Name        Loma Alta Station
#  ConnectionTypeID                   32
#  Amps                              NaN
#  Voltage                           NaN
#  PowerKW                         350.0
#  Quantity                            6
#  Comments                          NaN
#  Name: 147, dtype: object,
#  Latitude                                         33.553117
#  Longitude                                      -112.269044
#  Station_Name        Park West Shopping Mall - Supercharger
#  ConnectionTypeID                                        27
#  Amps                                                   NaN
#  Voltage                                                NaN
#  PowerKW                                              250.0
#  Quantity                                                16
#  Comments                                               NaN
#  Name: 149, dtype: object,
#  Latitude                                36.171569
#  Longitude                             -115.207247
#  Station_Name        Planet Fitness - Supercharger
#  ConnectionTypeID                               27
#  Amps                                          NaN
#  Voltage                                       NaN
#  PowerKW                                     250.0
#  Quantity                                       20
#  Comments                                      NaN
#  Name: 151, dtype: object,
#  Latitude                        36.030096
#  Longitude                     -115.135809
#  Station_Name        Subway - Supercharger
#  ConnectionTypeID                       27
#  Amps                                  NaN
#  Voltage                               NaN
#  PowerKW                             250.0
#  Quantity                               24
#  Comments                              NaN
#  Name: 153, dtype: object,
#  Latitude                       36.14618
#  Longitude                    -115.06522
#  Station_Name        Winterwood Pavilion
#  ConnectionTypeID                     32
#  Amps                                NaN
#  Voltage                             NaN
#  PowerKW                           350.0
#  Quantity                              4
#  Comments                            NaN
#  Name: 155, dtype: object,
#  Latitude                       36.14618
#  Longitude                    -115.06522
#  Station_Name        Winterwood Pavilion
#  ConnectionTypeID                     27
#  Amps                                NaN
#  Voltage                             NaN
#  PowerKW                           100.0
#  Quantity                              2
#  Comments                            NaN
#  Name: 157, dtype: object,
#  Latitude                        42.970555
#  Longitude                      -78.741325
#  Station_Name        North Ellicott Street
#  ConnectionTypeID                        1
#  Amps                                 45.0
#  Voltage                             240.0
#  PowerKW                              11.0
#  Quantity                                1
#  Comments                              NaN
#  Name: 159, dtype: object,
#  Latitude                                44.02594
#  Longitude                            -116.925288
#  Station_Name        HOMETOWN CHEVROLET BUICK GMC
#  ConnectionTypeID                               1
#  Amps                                         NaN
#  Voltage                                      NaN
#  PowerKW                                     19.2
#  Quantity                                       1
#  Comments                                     NaN
#  Name: 161, dtype: object,
#  Latitude                 43.619653
#  Longitude              -116.296774
#  Station_Name        BRONCO HYUNDAI
#  ConnectionTypeID                 2
#  Amps                           NaN
#  Voltage                        NaN
#  PowerKW                       62.5
#  Quantity                         2
#  Comments                       NaN
#  Name: 163, dtype: object,
#  Latitude             46.416323
#  Longitude          -117.006162
#  Station_Name          Leweston
#  ConnectionTypeID            32
#  Amps                       NaN
#  Voltage                    NaN
#  PowerKW                  200.0
#  Quantity                     2
#  Comments                   NaN
#  Name: 165, dtype: object,
#  Latitude                              37.602199
#  Longitude                             -122.3929
#  Station_Name        City of Millbrae - Broadway
#  ConnectionTypeID                             32
#  Amps                                        NaN
#  Voltage                                     NaN
#  PowerKW                                    50.0
#  Quantity                                      3
#  Comments                                    NaN
#  Name: 167, dtype: object,
#  Latitude                          40.334059
#  Longitude                       -104.985139
#  Station_Name        Buc-ee's - Supercharger
#  ConnectionTypeID                         27
#  Amps                                    NaN
#  Voltage                                 NaN
#  PowerKW                               250.0
#  Quantity                                 12
#  Comments                                NaN
#  Name: 169, dtype: object,
#  Latitude                                 39.817877
#  Longitude                              -104.773308
#  Station_Name        Starbucks - Tesla Supercharger
#  ConnectionTypeID                                27
#  Amps                                           NaN
#  Voltage                                        NaN
#  PowerKW                                      250.0
#  Quantity                                         8
#  Comments                                       NaN
#  Name: 171, dtype: object,
#  Latitude                                       41.582483
#  Longitude                                    -109.260376
#  Station_Name        Kroger Smiths 182 (Rock Springs, WY)
#  ConnectionTypeID                                      32
#  Amps                                                 NaN
#  Voltage                                              NaN
#  PowerKW                                            350.0
#  Quantity                                               6
#  Comments                                             NaN
#  Name: 173, dtype: object,
#  Latitude                           29.784357
#  Longitude                         -95.673623
#  Station_Name        WHOUSTON / 250 GENESIS 3
#  ConnectionTypeID                          32
#  Amps                                     NaN
#  Voltage                                  NaN
#  PowerKW                                 62.5
#  Quantity                                   4
#  Comments                                 NaN
#  Name: 175, dtype: object,
#  Latitude             29.783749
#  Longitude           -95.632932
#  Station_Name        BP Gigahub
#  ConnectionTypeID            32
#  Amps                       NaN
#  Voltage                    NaN
#  PowerKW                  150.0
#  Quantity                    22
#  Comments                   NaN
#  Name: 177, dtype: object,
#  Latitude                                           29.174166
#  Longitude                                         -96.278443
#  Station_Name        Enel X - ZIP IN ZIP OUT Exxon Truck Stop
#  ConnectionTypeID                                          32
#  Amps                                                     NaN
#  Voltage                                                  NaN
#  PowerKW                                                180.0
#  Quantity                                                   4
#  Comments                                                 NaN
#  Name: 179, dtype: object,
#  Latitude            29.356393
#  Longitude          -98.542113
#  Station_Name           Target
#  ConnectionTypeID           32
#  Amps                      NaN
#  Voltage                   NaN
#  PowerKW                 100.0
#  Quantity                    2
#  Comments                  NaN
#  Name: 181, dtype: object,
#  Latitude                                 32.216549
#  Longitude                               -95.824644
#  Station_Name        Taco Casa/Shell - Supercharger
#  ConnectionTypeID                                27
#  Amps                                           NaN
#  Voltage                                        NaN
#  PowerKW                                      250.0
#  Quantity                                         8
#  Comments                                       NaN
#  Name: 183, dtype: object,
#  Latitude                        26.160051
#  Longitude                      -97.877591
#  Station_Name        Pilot - Superchargers
#  ConnectionTypeID                       27
#  Amps                                  NaN
#  Voltage                               NaN
#  PowerKW                             250.0
#  Quantity                               12
#  Comments                              NaN
#  Name: 185, dtype: object,
#  Latitude                             30.706459
#  Longitude                          -101.202649
#  Station_Name        Sonic - Tesla Supercharger
#  ConnectionTypeID                            27
#  Amps                                       NaN
#  Voltage                                    NaN
#  PowerKW                                  250.0
#  Quantity                                    12
#  Comments                                   NaN
#  Name: 187, dtype: object,
#  Latitude                 43.111406
#  Longitude               -89.511778
#  Station_Name        Middleton Ford
#  ConnectionTypeID                32
#  Amps                         300.0
#  Voltage                        NaN
#  PowerKW                      240.0
#  Quantity                         2
#  Comments                       NaN
#  Name: 189, dtype: object,
#  Latitude                           30.84022
#  Longitude                        -87.775643
#  Station_Name        Chuck Stevens Chevrolet
#  ConnectionTypeID                         32
#  Amps                                  300.0
#  Voltage                               950.0
#  PowerKW                               120.0
#  Quantity                                  2
#  Comments             All Major Credit Cards
#  Name: 191, dtype: object,
#  Latitude                         30.861283
#  Longitude                       -87.777262
#  Station_Name            Chuck Stevens Ford
#  ConnectionTypeID                        32
#  Amps                                 200.0
#  Voltage                                NaN
#  PowerKW                              120.0
#  Quantity                                 2
#  Comments            All Major Credit Cards
#  Name: 193, dtype: object,
#  Latitude                    30.405051
#  Longitude                  -97.673384
#  Station_Name        Tech Ridge Center
#  ConnectionTypeID                    2
#  Amps                              NaN
#  Voltage                           NaN
#  PowerKW                         100.0
#  Quantity                            2
#  Comments                          NaN
#  Name: 195, dtype: object,
#  Latitude                    30.405051
#  Longitude                  -97.673384
#  Station_Name        Tech Ridge Center
#  ConnectionTypeID                   32
#  Amps                              NaN
#  Voltage                           NaN
#  PowerKW                         100.0
#  Quantity                            2
#  Comments                          NaN
#  Name: 197, dtype: object,
#  Latitude                       30.196316
#  Longitude                     -97.777046
#  Station_Name        South Congress Plaza
#  ConnectionTypeID                      32
#  Amps                                 NaN
#  Voltage                              NaN
#  PowerKW                            350.0
#  Quantity                               2
#  Comments                             NaN
#  Name: 199, dtype: object,
#  Latitude                                      30.226042
#  Longitude                                    -97.821704
#  Station_Name        Sunset Valley Village Shopping Mall
#  ConnectionTypeID                                      2
#  Amps                                                NaN
#  Voltage                                             NaN
#  PowerKW                                           100.0
#  Quantity                                              6
#  Comments                                            NaN
#  Name: 201, dtype: object,
#  Latitude                                      30.226042
#  Longitude                                    -97.821704
#  Station_Name        Sunset Valley Village Shopping Mall
#  ConnectionTypeID                                     32
#  Amps                                                NaN
#  Voltage                                             NaN
#  PowerKW                                           100.0
#  Quantity                                              2
#  Comments                                            NaN
#  Name: 203, dtype: object,
#  Latitude              30.534868
#  Longitude            -97.817827
#  Station_Name        Whole Foods
#  ConnectionTypeID             32
#  Amps                        NaN
#  Voltage                     NaN
#  PowerKW                   350.0
#  Quantity                      2
#  Comments                    NaN
#  Name: 205, dtype: object,
#  Latitude                         29.464945
#  Longitude                       -95.093802
#  Station_Name        Bay Colony Town Center
#  ConnectionTypeID                        32
#  Amps                                   NaN
#  Voltage                                NaN
#  PowerKW                              350.0
#  Quantity                                 6
#  Comments                               NaN
#  Name: 207, dtype: object,
#  Latitude                   42.202165
#  Longitude                 -71.837426
#  Station_Name        EVgo Auburn Mall
#  ConnectionTypeID                   2
#  Amps                             NaN
#  Voltage                          NaN
#  PowerKW                         50.0
#  Quantity                           2
#  Comments                         NaN
#  Name: 209, dtype: object,
#  Latitude                         29.779328
#  Longitude                       -95.952182
#  Station_Name        Flying J Travel Center
#  ConnectionTypeID                        32
#  Amps                                   NaN
#  Voltage                                NaN
#  PowerKW                              350.0
#  Quantity                                 4
#  Comments                               NaN
#  Name: 211, dtype: object,
#  Latitude                                     38.067276
#  Longitude                                  -120.188252
#  Station_Name        The Lodge Christian Retreat Center
#  ConnectionTypeID                                     1
#  Amps                                               NaN
#  Voltage                                          230.0
#  PowerKW                                            9.6
#  Quantity                                             2
#  Comments                                           NaN
#  Name: 213, dtype: object,
#  Latitude                       32.836458
#  Longitude                     -96.829611
#  Station_Name        Shops at Mockingbird
#  ConnectionTypeID                       2
#  Amps                                 NaN
#  Voltage                              NaN
#  PowerKW                            100.0
#  Quantity                               4
#  Comments                             NaN
#  Name: 215, dtype: object,
#  Latitude                       41.194279
#  Longitude                     -96.632622
#  Station_Name        Sid Dillon Chevrolet
#  ConnectionTypeID                       1
#  Amps                                 NaN
#  Voltage                              NaN
#  PowerKW                             19.2
#  Quantity                               1
#  Comments                             NaN
#  Name: 217, dtype: object,
#  Latitude             41.978298
#  Longitude          -100.567763
#  Station_Name          Sandoz'r
#  ConnectionTypeID             2
#  Amps                       NaN
#  Voltage                    NaN
#  PowerKW                   62.5
#  Quantity                     2
#  Comments                   NaN
#  Name: 219, dtype: object,
#  Latitude                   43.527965
#  Longitude                  -96.78681
#  Station_Name        Sioux Falls Ford
#  ConnectionTypeID                  32
#  Amps                             NaN
#  Voltage                          NaN
#  PowerKW                         25.0
#  Quantity                           3
#  Comments                         NaN
#  Name: 221, dtype: object,
#  Latitude                        32.456461
#  Longitude                       -93.74507
#  Station_Name        Rhino Coffee - Uptown
#  ConnectionTypeID                        1
# ...
#  PowerKW                                                           3.7
#  Quantity                                                            2
#  Comments            kW power is an estimate based on the connectio...
#  Name: 1197, dtype: object,
#  Latitude                                                    40.280428
#  Longitude                                                  -74.295106
#  Station_Name                                   Freehold Chrysler Jeep
#  ConnectionTypeID                                                    1
#  Amps                                                             16.0
#  Voltage                                                         230.0
#  PowerKW                                                           3.7
#  Quantity                                                            2
#  Comments            kW power is an estimate based on the connectio...
#  Name: 1199, dtype: object,
#  Latitude                                                    40.276992
#  Longitude                                                  -74.705153
#  Station_Name                             Precision Acura of Princeton
#  ConnectionTypeID                                                    1
#  Amps                                                             16.0
#  Voltage                                                         230.0
#  PowerKW                                                           3.7
#  Quantity                                                            1
#  Comments            kW power is an estimate based on the connectio...
#  Name: 1201, dtype: object,
#  Latitude                                                    40.268842
#  Longitude                                                   -74.47662
#  Station_Name                          MONROE CROSSING MONROE CROSSING
#  ConnectionTypeID                                                    1
#  Amps                                                             16.0
#  Voltage                                                         230.0
#  PowerKW                                                           3.7
#  Quantity                                                            2
#  Comments            kW power is an estimate based on the connectio...
#  Name: 1203, dtype: object,
#  Latitude                                                    40.233056
#  Longitude                                                  -74.734134
#  Station_Name                                         Isles - Mill One
#  ConnectionTypeID                                                    1
#  Amps                                                             16.0
#  Voltage                                                         230.0
#  PowerKW                                                           3.7
#  Quantity                                                            4
#  Comments            kW power is an estimate based on the connectio...
#  Name: 1205, dtype: object,
#  Latitude                                                    40.228107
#  Longitude                                                  -74.171867
#  Station_Name                                AATZ HOLDING LL TALL OAKS
#  ConnectionTypeID                                                    1
#  Amps                                                             16.0
#  Voltage                                                         230.0
#  PowerKW                                                           3.7
#  Quantity                                                            2
#  Comments            kW power is an estimate based on the connectio...
#  Name: 1207, dtype: object,
#  Latitude                                                    40.211576
#  Longitude                                                  -74.089635
#  Station_Name                            EVIA Jumping Brook Apartments
#  ConnectionTypeID                                                    1
#  Amps                                                             16.0
#  Voltage                                                         230.0
#  PowerKW                                                           3.7
#  Quantity                                                            2
#  Comments            kW power is an estimate based on the connectio...
#  Name: 1209, dtype: object,
#  Latitude                                                    40.199788
#  Longitude                                                  -76.722356
#  Station_Name                                           Mid-Town Plaza
#  ConnectionTypeID                                                    1
#  Amps                                                             16.0
#  Voltage                                                         230.0
#  PowerKW                                                           3.7
#  Quantity                                                            2
#  Comments            kW power is an estimate based on the connectio...
#  Name: 1211, dtype: object,
#  Latitude                                                    40.157559
#  Longitude                                                  -76.389038
#  Station_Name                                              Hondru Ford
#  ConnectionTypeID                                                    1
#  Amps                                                             16.0
#  Voltage                                                         230.0
#  PowerKW                                                           3.7
#  Quantity                                                            1
#  Comments            kW power is an estimate based on the connectio...
#  Name: 1213, dtype: object,
#  Latitude                                                    40.146095
#  Longitude                                                  -74.436349
#  Station_Name        Six Flags Entertainment Corporation Great Adve...
#  ConnectionTypeID                                                    1
#  Amps                                                             16.0
#  Voltage                                                         230.0
#  PowerKW                                                           3.7
#  Quantity                                                            8
#  Comments            kW power is an estimate based on the connectio...
#  Name: 1215, dtype: object,
#  Latitude                                                    40.122456
#  Longitude                                                  -74.976768
#  Station_Name                           FAULKNERTOYOTA FAULKNERTOYOTA1
#  ConnectionTypeID                                                    1
#  Amps                                                             16.0
#  Voltage                                                         230.0
#  PowerKW                                                           3.7
#  Quantity                                                            1
#  Comments            kW power is an estimate based on the connectio...
#  Name: 1217, dtype: object,
#  Latitude                                                    40.110701
#  Longitude                                                  -76.476623
#  Station_Name                            Whitmoyer Chevrolet Mount Joy
#  ConnectionTypeID                                                   32
#  Amps                                                              NaN
#  Voltage                                                           NaN
#  PowerKW                                                          50.0
#  Quantity                                                            1
#  Comments            kW power is an estimate based on the connectio...
#  Name: 1219, dtype: object,
#  Latitude                                                     40.10841
#  Longitude                                                  -75.114356
#  Station_Name                                    RYDAL PARK RYDAL MAIN
#  ConnectionTypeID                                                    1
#  Amps                                                             16.0
#  Voltage                                                         230.0
#  PowerKW                                                           3.7
#  Quantity                                                            2
#  Comments            kW power is an estimate based on the connectio...
#  Name: 1221, dtype: object,
#  Latitude                                                     40.08815
#  Longitude                                                   -76.34629
#  Station_Name                               LCM HYUNDAI LCM HY CUST FC
#  ConnectionTypeID                                                    2
#  Amps                                                              NaN
#  Voltage                                                           NaN
#  PowerKW                                                          50.0
#  Quantity                                                            1
#  Comments            kW power is an estimate based on the connectio...
#  Name: 1223, dtype: object,
#  Latitude                                                    40.080805
#  Longitude                                                  -74.088508
#  Station_Name                                            AAF STATION 3
#  ConnectionTypeID                                                    1
#  Amps                                                             16.0
#  Voltage                                                         230.0
#  PowerKW                                                           3.7
#  Quantity                                                            2
#  Comments            kW power is an estimate based on the connectio...
#  Name: 1225, dtype: object,
#  Latitude                                                     40.06888
#  Longitude                                                  -75.445579
#  Station_Name                                      EMBER PARKING LOT 2
#  ConnectionTypeID                                                    1
#  Amps                                                             16.0
#  Voltage                                                         230.0
#  PowerKW                                                           3.7
#  Quantity                                                            2
#  Comments            kW power is an estimate based on the connectio...
#  Name: 1227, dtype: object,
#  Latitude                                                    40.068226
#  Longitude                                                  -75.306897
#  Station_Name                         300 Four Falls - Parking Level 6
#  ConnectionTypeID                                                    1
#  Amps                                                             16.0
#  Voltage                                                         230.0
#  PowerKW                                                           3.7
#  Quantity                                                            2
#  Comments            kW power is an estimate based on the connectio...
#  Name: 1229, dtype: object,
#  Latitude                                                    40.060283
#  Longitude                                                  -85.651274
#  Station_Name                                  GM - ED MARTIN CADILLAC
#  ConnectionTypeID                                                   32
#  Amps                                                              NaN
#  Voltage                                                           NaN
#  PowerKW                                                          50.0
#  Quantity                                                            1
#  Comments            kW power is an estimate based on the connectio...
#  Name: 1231, dtype: object,
#  Latitude                                                    40.049051
#  Longitude                                                  -80.642271
#  Station_Name                               Wheeling Subaru Volkswagen
#  ConnectionTypeID                                                    1
#  Amps                                                             16.0
#  Voltage                                                         230.0
#  PowerKW                                                           3.7
#  Quantity                                                            1
#  Comments            kW power is an estimate based on the connectio...
#  Name: 1233, dtype: object,
#  Latitude                                                    40.026348
#  Longitude                                                  -86.013341
#  Station_Name                                        CENTERPOINT NOB 1
#  ConnectionTypeID                                                    1
#  Amps                                                             16.0
#  Voltage                                                         230.0
#  PowerKW                                                           3.7
#  Quantity                                                            1
#  Comments            kW power is an estimate based on the connectio...
#  Name: 1235, dtype: object,
#  Latitude                                                     39.99998
#  Longitude                                                   -76.18514
#  Station_Name                                              Solar Hotel
#  ConnectionTypeID                                                    1
#  Amps                                                             16.0
#  Voltage                                                         230.0
#  PowerKW                                                           3.7
#  Quantity                                                            8
#  Comments            kW power is an estimate based on the connectio...
#  Name: 1237, dtype: object,
#  Latitude                                                    39.992539
#  Longitude                                                   -74.17329
#  Station_Name                                     Lotano Speedy & Sons
#  ConnectionTypeID                                                    1
#  Amps                                                             16.0
#  Voltage                                                         230.0
#  PowerKW                                                           3.7
#  Quantity                                                            1
#  Comments            kW power is an estimate based on the connectio...
#  Name: 1239, dtype: object,
#  Latitude                                                     39.98507
#  Longitude                                                  -105.22944
#  Station_Name                                         Iconergy Boulder
#  ConnectionTypeID                                                    1
#  Amps                                                             16.0
#  Voltage                                                         230.0
#  PowerKW                                                           3.7
#  Quantity                                                            4
#  Comments            kW power is an estimate based on the connectio...
#  Name: 1241, dtype: object,
#  Latitude                                                    39.967285
#  Longitude                                                  -83.006446
#  Station_Name                             LAZ COLUMBUS OH MARCONI BLVD
#  ConnectionTypeID                                                    1
#  Amps                                                             16.0
#  Voltage                                                         230.0
#  PowerKW                                                           3.7
#  Quantity                                                            2
#  Comments            kW power is an estimate based on the connectio...
#  Name: 1243, dtype: object,
#  Latitude                      39.959384
#  Longitude                    -83.368994
#  Station_Name        Pilot Travel Center
#  ConnectionTypeID                     32
#  Amps                                NaN
#  Voltage                             NaN
#  PowerKW                           350.0
#  Quantity                              4
#  Comments
#  Name: 1245, dtype: object]

# %% [markdown]
# Next step is that modeling the problem considering exact distances, remaining battery after each segment, charging durations, and possibly charging costs.
#
# ## Visualization
#
# a. Plot the Route and Charging Stations

# %%
selected_stops_df = pd.DataFrame(selected_stops)

# %%
# Initialize map centered at the origin
m = folium.Map(location=[origin.latitude, origin.longitude], zoom_start=13)

# Plot the route
route_latlng = [(G.nodes[node]['y'], G.nodes[node]['x']) for node in route]
folium.PolyLine(route_latlng, color="blue", weight=5, opacity=0.8).add_to(m)

# Plot charging stations
for idx, row in selected_stops_df.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=row['Station_Name'],
        icon=folium.Icon(color='green', icon='bolt', prefix='fa')
    ).add_to(m)

# Display the map
m.save("/content/drive/MyDrive/Renewable_Energy/ev_route.html")

# %% [markdown]
# b. Display the Map
#
# Open the generated ev_route.html in a web browser to interactively view the optimized route and charging stops.
